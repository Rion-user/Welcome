# %% [markdown]
# <a href="https://colab.research.google.com/github/Rion-user/Welcome/blob/master/crawling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 기본설정

# %%
# 설치
# !pip install xmltodict
# !pip install load_dotenv
# !pip install requests
# !pip install tqdm
# Out:
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: load_dotenv in /usr/local/lib/python3.10/dist-packages (0.1.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from load_dotenv) (1.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)

# %%
# 라이브러리 호출
import requests
import xmltodict
import json
import os
from dotenv import load_dotenv
from tqdm import tqdm

# %%
OC = 'nellcome4636'

# %%
# mst 정보들
same_jo_mst = ['231757', '238041', '236053', '213977', '242921', '223449', '245983', '224303', '232611', '218017', '234021', '231661', '213811', '233995', '245343', '243993', '228085', '166366', '195415', '245971', '137358', '188534', '158177', '218015', '244995', '237543', '205685', '245285', '223459', '203981', '171102', '195440', '228887', '243699', '241185', '236195', '241801', '245381', '239485', '245657', '153871', '224547', '243849', '243921', '218013', '211459', '169762', '199748', '246567', '198221', '218055', '213551', '212307', '243853', '238047', '238759', '246281', '183899', '102534', '231601', '217291', '238827', '247271', '245379', '245245', '237883', '195351', '209662', '181386', '223077', '224669', '238855', '206734', '245989', '241249', '192584', '193381', '230783', '224575', '180744', '219403', '241921', '242993', '213225', '232855', '238227', '165539', '192490', '177160', '242873', '234295', '223491', '237401', '228669', '174491', '244377', '186157', '245979', '210145', '205795', '195869', '205996', '244087', '238063', '243045', '230683', '195116', '232959', '227825', '188376', '97990', '234909', '195544', '243669', '113181', '234131', '237861', '243817', '228655', '238039', '224961', '244037', '206085', '203812', '239995', '183706', '112289', '192519', '206564', '218917', '236001', '203531', '215909', '218301', '245009', '238935', '245297', '239261', '211455', '195055', '195398', '232587', '243705', '142443', '228259', '245307', '195117', '209730', '121947', '210726', '230729', '244961', '195051', '242945', '195056', '243113', '208453', '246835', '231457', '198547', '239293', '203247', '236223', '168005', '211727', '116110', '195047', '241237', '195331', '195378', '203305', '232185', '231627', '238229', '242713', '238053', '222505', '228111', '243153', '230549', '236231', '214437', '242363', '81706', '243057', '238119', '240077', '149559', '245849', '231367', '195529', '195997', '215653', '204695', '183569', '195137', '212227', '55761', '211527', '232647', '234707', '236819', '245351', '239241', '231721', '222899', '244183', '192309', '236771', '223451', '150692', '179005', '230157', '239617', '228131', '244779', '234277', '91137', '224533', '245367', '243675', '241169', '246295', '235283', '195322', '195497', '136944', '238861', '247269', '245315', '232643', '239979', '96889', '166367', '228147', '237105', '201148', '205997', '218873', '241043', '236955', '81895', '234409', '217403', '234333', '245981', '202628', '213449', '201184', '245371', '112303', '218717', '208382', '239245', '130810', '234325', '194499', '183597', '236201', '245015', '170996', '167959', '237137', '86731', '219033', '149917', '184935', '220965', '212233', '242929', '242923', '203259', '242007', '224927', '195894', '183520', '184205', '239271', '245235', '179033', '224655', '114744', '213855', '238109', '239269', '234671', '242095', '181623', '246637', '219039', '109707', '129332', '176245', '122694', '213837', '227321', '240031', '230525', '232881', '247249', '234281', '200682', '232879', '216107', '231503', '246853', '230431', '208381', '218907', '117325', '236251', '237359', '228087', '240097', '121956', '210257', '209699', '223983', '244711', '216183', '231795', '242949', '243041', '242881', '240055', '138747', '228115', '166688', '238801', '204777', '165852', '219135', '244275', '219239', '252049', '236111', '239259', '235203', '84504', '208541', '230497', '201190', '93181', '218135', '233211', '244919', '245289', '199798', '243063', '205846', '204560', '240065', '140592', '216173', '238257', '195501', '243065', '249059', '228121', '232893', '242999', '234911', '243059', '230805', '230513', '244969', '234675', '97987', '119410', '239303', '232199', '190607', '182009', '218865', '217995', '221707', '242989', '214441', '236321', '204775', '241159', '239469', '243115', '169467', '195052', '188047', '243379', '243965', '106831', '238793', '244367', '207953', '103946', '211885', '203671', '198486', '241157', '244133', '232869', '191150', '83896', '211551', '179505', '243061', '218487', '228169', '247231', '205930', '152098', '165523', '219353', '238243', '240069', '205742', '240351', '108467', '222423', '214319', '91501', '214473', '228749', '219067', '178983', '243177', '217299', '117324', '148466', '231373', '223431', '245305', '196333', '205811', '235545', '214193', '169502', '203249', '245265', '195068', '243563', '238655', '237135', '213857', '240025', '219563', '198564', '198226', '216103', '217981', '243939', '202626', '238867', '244035', '242953', '230353', '224107', '216179', '215763', '220373', '231391', '113964', '130656', '202774', '115683', '231369', '240033', '208601', '231755', '195536', '242983', '103863', '164562', '185019', '224583', '178989', '244943', '237891', '204767', '231491', '242941', '180465', '224671', '201143', '213527', '234017', '149922', '242361', '176090', '239491', '192435', '88893', '136693', '223615', '239477', '234569', '248315', '231331', '92106', '244277', '122986', '200173', '129262', '232671', '203835', '197503', '121952', '103947', '242937', '232897', '242823', '243099', '104326', '237439', '202765', '213779', '235555', '218051', '245393', '213783', '103962', '208452', '218005', '199779', '234339', '234825', '232191', '246917', '232081', '136692', '244701', '86411', '232841', '241529', '136014', '234299', '238915', '244039', '170988', '91382', '240571', '202910', '230223', '235999', '236145', '203170', '199122', '232253', '231377', '237433', '240071', '182175', '103228', '122701', '231537', '214535', '238097', '238919', '218661', '224695', '205801', '213809', '232231', '212141', '238805', '97989', '238057', '231823', '229311', '168725', '117424', '224385', '192412', '246157', '136917', '230677', '229829', '238893', '244993', '91383', '210258', '214403', '237131', '205255', '220877', '244739', '244801', '214551', '237517', '237515', '244267', '245349', '198474', '97050', '245031', '206142', '244033', '230421', '231375', '244921', '245001', '231495', '239273', '228735', '206470', '103869', '249977', '238061', '188538', '98243', '213519', '195078', '235587', '216131', '244627', '228083', '236951', '238751', '241541', '213803', '239893', '84010', '236817', '205700', '90415', '231701', '239301', '214161', '246123', '157319', '194522', '209645', '241935', '122990', '211799', '204768', '92068', '234455', '240245', '234271', '236113', '192018', '203669', '199499', '218325', '180327', '244609', '237421', '199083', '245917', '206394', '208699', '243671', '219361', '188381', '243147', '241139', '243073', '218903', '166363', '242019', '247189', '223575', '216151', '96895', '227407', '232201', '195072', '236229', '242979', '217243', '136666', '235839', '230161', '241573', '242947', '162682', '242933', '195667', '228817', '238681', '206701', '245281', '244931', '231863', '219093', '238099', '167953', '113196', '199494', '222549', '244933', '224923', '210268', '243667', '208446', '214129', '223079', '219131', '232139', '244975', '242931', '245851', '244119', '239493', '172201', '212189', '219139', '223461', '91380', '244703', '245987', '231425', '249619', '238833', '242939', '153866', '234349', '167446', '220883', '210368', '218143', '149822', '245227', '142442', '217691', '231397', '203169', '195354', '241317', '194762', '222441', '244253', '245975', '218113', '112382', '243665', '136675', '234413', '230255', '222489', '228071', '211635', '244965', '241807', '232271', '233381', '238235', '213521', '83895', '114769', '233407', '242919', '208425', '233829', '245653', '218155', '195716', '245003', '103861', '199773', '195091', '224917', '195200', '247139', '215905', '220857', '209867', '235571', '244927', '242891', '212091', '169302', '238253', '219107', '149564', '202316', '205233', '198482', '234719', '195470', '201137', '106754', '214237', '219091', '215923', '238835', '210363', '103864', '244855', '218153', '150369', '173112', '195345', '239311', '232387', '132928', '238789', '245737', '238845', '238757']
diff_jo_mst = ['243117', '239547', '218909', '233961', '246165', '228175', '243935', '237355', '105295', '245747', '238059', '235619', '149585', '243079', '239541', '242955', '243171', '61603', '237087', '222429', '234849', '241829', '214545', '203739', '228065', '246569', '242975', '238335', '195316', '236317', '199495', '238763', '235535', '113175', '238797', '180480', '244997', '224549', '149553', '240063', '232225', '228113', '195441', '225139', '228089', '230449', '230781', '238113', '232563', '210266', '230429', '233423', '239291', '245973', '242401']
err_mst = [('153886', 'unknown', 'need to check'), ('165498', 'unknown', 'need to check'), ('231781', 'unknown', 'need to check')]

# %% [markdown]
# # 데이터 불러오기
# (테스트용)

# %%
http://www.law.go.kr/DRF/lawSearch.do?target=elaw
http://www.law.go.kr/DRF/lawService.do?target=elaw

# %%
list_url = f'http://www.law.go.kr/DRF/lawSearch.do?OC={OC}&target=elaw&page={1}&display=100'
#list_url = f'http://www.law.go.kr/DRF/lawService.do?OC={OC}&target=elaw&ID="231757"'
response = requests.get(list_url)
json_data = xmltodict.parse(response.text)

# %%
list_url = f'http://www.law.go.kr/DRF/lawService.do?OC={OC}&target=elaw'
response = requests.get(list_url)
json_data = xmltodict.parse(response.text)

# %%
json_data
# Out:
# {'LawSearch': {'target': 'elaw',
#   '키워드': '*',
#   'section': 'lawNm',
#   'totalCnt': '2587',
#   'page': '1',
#   'law': [{'@id': '1',
#     '법령일련번호': '236231',
#     '현행연혁코드': '현행',
#     '법령명한글': '119구조ㆍ구급에 관한 법률',
#     '법령명영문': 'ACT ON 119  RESCUE AND EMERGENCY MEDICAL SERVICES',
#     '법령ID': '011349',
#     '공포일자': '20211019',
#     '공포번호': '18487',
#     '제개정구분명': '일부개정',
#     '소관부처명': '소방청,소방청,소방청,소방청,소방청',
#     '법령구분명': '법률',
#     '시행일자': '20220120',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=236231&type=HTML&mobileYn='},
#    {'@id': '2',
#     '법령일련번호': '228807',
#     '현행연혁코드': '연혁',
#     '법령명한글': '119구조ㆍ구급에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE ACT ON 119  RESCUE AND EMERGENCY MEDICAL SERVICES',
#     '법령ID': '011452',
#     '공포일자': '20210121',
#     '공포번호': '31411',
#     '제개정구분명': '일부개정',
#     '소관부처명': '소방청,소방청,소방청,소방청,소방청',
#     '법령구분명': '대통령령',
#     '시행일자': '20210121',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=228807&type=HTML&mobileYn='},
#    {'@id': '3',
#     '법령일련번호': '243115',
#     '현행연혁코드': '현행',
#     '법령명한글': '1인 창조기업 육성에 관한 법률',
#     '법령명영문': 'ACT ON THE FOSTERING OF  SELF-EMPLOYED CREATIVE ENTERPRISES',
#     '법령ID': '011370',
#     '공포일자': '20220610',
#     '공포번호': '18961',
#     '제개정구분명': '일부개정',
#     '소관부처명': '중소벤처기업부',
#     '법령구분명': '법률',
#     '시행일자': '20221211',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=243115&type=HTML&mobileYn='},
#    {'@id': '4',
#     '법령일련번호': '195898',
#     '현행연혁코드': '연혁',
#     '법령명한글': '1인 창조기업 육성에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE ACT ON THE FOSTERING OF  SELF-EMPLOYED CREATIVE ENTERPRISES',
#     '법령ID': '011474',
#     '공포일자': '20170726',
#     '공포번호': '28213',
#     '제개정구분명': '타법개정',
#     '소관부처명': '중소벤처기업부',
#     '법령구분명': '대통령령',
#     '시행일자': '20170726',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=195898&type=HTML&mobileYn='},
#    {'@id': '5',
#     '법령일련번호': '191042',
#     '현행연혁코드': '연혁',
#     '법령명한글': '2011대구세계육상선수권대회, 2013충주세계조정선수권대회, 2014인천아시아경기대회, 2014인천장애인아시아경기대회 및 2015광주하계유니버시아드대회 지원법',
#     '법령명영문': 'ACT ON ASSISTANCE TO THE IAAF WORLD CHAMPIONSHIPS DAEGU 2011, THE 2013 WORLD ROWING CHAMPIONSHIPS CHUNGJU, THE 17TH 2014 INCHEON ASIAN GAMES, THE 2014 INCHEON ASIAN PARA GAMES, AND THE 2015 GWANGJU SUMMER UNIVERSIADE',
#     '법령ID': '010585',
#     '공포일자': '20170117',
#     '공포번호': '14532',
#     '제개정구분명': '타법개정',
#     '소관부처명': '문화체육관광부',
#     '법령구분명': '법률',
#     '시행일자': '20180118',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=191042&type=HTML&mobileYn='},
#    {'@id': '6',
#     '법령일련번호': '206430',
#     '현행연혁코드': '연혁',
#     '법령명한글': '2018 평창 동계올림픽대회 및 동계패럴림픽대회 지원 등에 관한 특별법',
#     '법령명영문': 'SPECIAL ACT ON SUPPORT FOR THE 2018 PYEONGCHANG OLYMPIC AND PARALYMPIC WINTER GAMES',
#     '법령ID': '011532',
#     '공포일자': '20181231',
#     '공포번호': '16172',
#     '제개정구분명': '타법개정',
#     '소관부처명': '문화체육관광부',
#     '법령구분명': '법률',
#     '시행일자': '20190401',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=206430&type=HTML&mobileYn='},
#    {'@id': '7',
#     '법령일련번호': '209598',
#     '현행연혁코드': '연혁',
#     '법령명한글': '2018 평창 동계올림픽대회 및 동계패럴림픽대회 지원 등에 관한 특별법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE SPECIAL ACT ON SUPPORT FOR THE 2018 PYEONGCHANG OLYMPIC AND PARALYMPIC WINTER GAMES',
#     '법령ID': '011679',
#     '공포일자': '20190702',
#     '공포번호': '29950',
#     '제개정구분명': '타법개정',
#     '소관부처명': '문화체육관광부',
#     '법령구분명': '대통령령',
#     '시행일자': '20190702',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=209598&type=HTML&mobileYn='},
#    {'@id': '8',
#     '법령일련번호': '205822',
#     '현행연혁코드': '연혁',
#     '법령명한글': '2023 새만금 세계스카우트잼버리 지원 특별법',
#     '법령명영문': 'SPECIAL ACT ON SUPPORT FOR THE 2023 SAEMANGEUM WORLD SCOUT JAMBOREE',
#     '법령ID': '013210',
#     '공포일자': '20181218',
#     '공포번호': '15984',
#     '제개정구분명': '제정',
#     '소관부처명': '여성가족부',
#     '법령구분명': '법률',
#     '시행일자': '20181218',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=205822&type=HTML&mobileYn='},
#    {'@id': '9',
#     '법령일련번호': '212307',
#     '현행연혁코드': '현행',
#     '법령명한글': '2023 새만금 세계스카우트잼버리 지원 특별법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE SPECIAL ACT ON SUPPORT FOR THE 2023 SAEMANGEUM WORLD SCOUT JAMBOREE',
#     '법령ID': '013626',
#     '공포일자': '20191210',
#     '공포번호': '30241',
#     '제개정구분명': '제정',
#     '소관부처명': '여성가족부',
#     '법령구분명': '대통령령',
#     '시행일자': '20191219',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=212307&type=HTML&mobileYn='},
#    {'@id': '10',
#     '법령일련번호': '162682',
#     '현행연혁코드': '현행',
#     '법령명한글': '4ㆍ16세월호참사 진상규명 및 안전사회 건설 등을 위한 특별법',
#     '법령명영문': 'SPECIAL ACT ON INVESTIGATING THE TRUTH OF THE16 SEWOL FERRY DISASTER AND BUILDING A SAFE SOCIETY',
#     '법령ID': '012159',
#     '공포일자': '20141119',
#     '공포번호': '12843',
#     '제개정구분명': '제정',
#     '소관부처명': '해양수산부',
#     '법령구분명': '법률',
#     '시행일자': '20150101',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=162682&type=HTML&mobileYn='},
#    {'@id': '11',
#     '법령일련번호': '220911',
#     '현행연혁코드': '연혁',
#     '법령명한글': '4ㆍ16세월호참사 피해구제 및 지원 등을 위한 특별법',
#     '법령명영문': 'SPECIAL ACT ON REMEDY FOR DAMAGE CAUSED BY THE APRIL 16 SEWOL FERRY DISASTER, ASSISTANCE THEREFOR, ETC.',
#     '법령ID': '012245',
#     '공포일자': '20200811',
#     '공포번호': '17472',
#     '제개정구분명': '타법개정',
#     '소관부처명': '국무조정실,해양수산부',
#     '법령구분명': '법률',
#     '시행일자': '20200912',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=220911&type=HTML&mobileYn='},
#    {'@id': '12',
#     '법령일련번호': '203834',
#     '현행연혁코드': '연혁',
#     '법령명한글': '4ㆍ16세월호참사 피해구제 및 지원 등을 위한 특별법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE SPECIAL ACT ON REMEDY FOR DAMAGE CAUSED BY THE APRIL 16 SEWOL FERRY DISASTER, ASSISTANCE THEREFOR, ETC.',
#     '법령ID': '012272',
#     '공포일자': '20180612',
#     '공포번호': '28970',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국무조정실,해양수산부',
#     '법령구분명': '대통령령',
#     '시행일자': '20180614',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=203834&type=HTML&mobileYn='},
#    {'@id': '13',
#     '법령일련번호': '234839',
#     '현행연혁코드': '연혁',
#     '법령명한글': '5ㆍ18민주유공자예우 및 단체설립에 관한 법률',
#     '법령명영문': 'ACT ON THE HONORABLE TREATMENT OF PERSONS OF DISTINGUISHED SERVICE TO THE MAY 18 DEMOCRATIZATION MOVEMENT AND ESTABLISHMENT OF RELATED ORGANIZATION',
#     '법령ID': '009289',
#     '공포일자': '20210817',
#     '공포번호': '18439',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국가보훈부,국가보훈부,국가보훈부,국가보훈부,국가보훈부,국가보훈부,국가보훈부,국가보훈부,국가보훈부,국가보훈부,국가보훈부,국가보훈부',
#     '법령구분명': '법률',
#     '시행일자': '20220218',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=234839&type=HTML&mobileYn='},
#    {'@id': '14',
#     '법령일련번호': '228079',
#     '현행연혁코드': '연혁',
#     '법령명한글': '5ㆍ18민주화운동 등에 관한 특별법',
#     '법령명영문': 'SPECIAL ACT ON THE MAY 18 DEMOCRATIZATION MOVEMENT',
#     '법령ID': '001159',
#     '공포일자': '20210105',
#     '공포번호': '17823',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국방부,법무부',
#     '법령구분명': '법률',
#     '시행일자': '20210105',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=228079&type=HTML&mobileYn='},
#    {'@id': '15',
#     '법령일련번호': '228259',
#     '현행연혁코드': '현행',
#     '법령명한글': '5ㆍ18민주화운동 진상규명을 위한 특별법',
#     '법령명영문': 'SPECIAL ACT ON INVESTIGATING THE TRUTH OF THE MAY 18 DEMOCRATIZATION MOVEMENT',
#     '법령ID': '013091',
#     '공포일자': '20210105',
#     '공포번호': '17886',
#     '제개정구분명': '일부개정',
#     '소관부처명': '5.18민주화운동진상규명조사위원회',
#     '법령구분명': '법률',
#     '시행일자': '20210206',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=228259&type=HTML&mobileYn='},
#    {'@id': '16',
#     '법령일련번호': '245979',
#     '현행연혁코드': '현행',
#     '법령명한글': '6ㆍ25 전사자유해의 발굴 등에 관한 법률',
#     '법령명영문': 'ACT ON THE EXCAVATION OF THE REMAINS OF SOLDIERS KILLED IN THE KOREAN WAR',
#     '법령ID': '010716',
#     '공포일자': '20221213',
#     '공포번호': '19071',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국방부',
#     '법령구분명': '법률',
#     '시행일자': '20221213',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=245979&type=HTML&mobileYn='},
#    {'@id': '17',
#     '법령일련번호': '204768',
#     '현행연혁코드': '현행',
#     '법령명한글': '6ㆍ25전쟁 납북피해 진상규명 및 납북피해자 명예회복에 관한 법률',
#     '법령명영문': 'ACT ON FINDING THE TRUTH OF THE DAMAGE FROM NORTH KOREA’S ABDUCTION DURING THE KOREAN WAR AND RESTORING HONOR OF THE VICTIMS',
#     '법령ID': '011176',
#     '공포일자': '20181016',
#     '공포번호': '15790',
#     '제개정구분명': '일부개정',
#     '소관부처명': '통일부',
#     '법령구분명': '법률',
#     '시행일자': '20181016',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=204768&type=HTML&mobileYn='},
#    {'@id': '18',
#     '법령일련번호': '195536',
#     '현행연혁코드': '현행',
#     '법령명한글': '6ㆍ25전쟁 납북피해 진상규명 및 납북피해자 명예회복에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE ACT ON FINDING THE TRUTH OF THE DAMAGE FROM NORTH KOREA’S ABDUCTION DURING THE KOREAN WAR AND RESTORING HONOR OF THE VICTIMS',
#     '법령ID': '011285',
#     '공포일자': '20170726',
#     '공포번호': '28211',
#     '제개정구분명': '타법개정',
#     '소관부처명': '통일부',
#     '법령구분명': '대통령령',
#     '시행일자': '20170726',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=195536&type=HTML&mobileYn='},
#    {'@id': '19',
#     '법령일련번호': '238801',
#     '현행연혁코드': '현행',
#     '법령명한글': '6ㆍ25전쟁 무공훈장 수여 등에 관한 법률',
#     '법령명영문': 'ACT ON THE CONFERMENT OF ORDERS OF MILITARY MERIT FOR DISTINGUISHED SERVICES RENDERED DURING THE KOREAN WAR',
#     '법령ID': '013468',
#     '공포일자': '20220104',
#     '공포번호': '18679',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국방부',
#     '법령구분명': '법률',
#     '시행일자': '20220104',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=238801&type=HTML&mobileYn='},
#    {'@id': '20',
#     '법령일련번호': '231367',
#     '현행연혁코드': '현행',
#     '법령명한글': '6ㆍ25전쟁 전후 적 지역에서 활동한 비정규군 공로자 보상에 관한 법률',
#     '법령명영문': 'ACT ON COMPENSATION TO PERSONS OF DISTINGUISHED SERVICE WHO CONDUCTED OPERATIONS AS IRREGULAR FORCES IN ENEMY TERRITORIES BEFORE AND DURING THE KOREAN WAR',
#     '법령ID': '014062',
#     '공포일자': '20210413',
#     '공포번호': '17993',
#     '제개정구분명': '제정',
#     '소관부처명': '국방부',
#     '법령구분명': '법률',
#     '시행일자': '20211014',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=231367&type=HTML&mobileYn='},
#    {'@id': '21',
#     '법령일련번호': '236013',
#     '현행연혁코드': '연혁',
#     '법령명한글': '6ㆍ25전쟁 전후 적 지역에서 활동한 비정규군 공로자 보상에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE ACT ON COMPENSATION TO PERSONS OF DISTINGUISHED SERVICE WHO CONDUCTED OPERATIONS AS IRREGULAR FORCES IN ENEMY TERRITORIES BEFORE AND DURING THE KOREAN WAR',
#     '법령ID': '014166',
#     '공포일자': '20211014',
#     '공포번호': '32037',
#     '제개정구분명': '제정',
#     '소관부처명': '국방부',
#     '법령구분명': '대통령령',
#     '시행일자': '20211014',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=236013&type=HTML&mobileYn='},
#    {'@id': '22',
#     '법령일련번호': '188538',
#     '현행연혁코드': '현행',
#     '법령명한글': '가등기담보 등에 관한 법률',
#     '법령명영문': 'PROVISIONAL REGISTRATION SECURITY ACT',
#     '법령ID': '001257',
#     '공포일자': '20161227',
#     '공포번호': '14474',
#     '제개정구분명': '타법개정',
#     '소관부처명': '법무부',
#     '법령구분명': '법률',
#     '시행일자': '20170328',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=188538&type=HTML&mobileYn='},
#    {'@id': '23',
#     '법령일련번호': '238849',
#     '현행연혁코드': '연혁',
#     '법령명한글': '가맹사업거래의 공정화에 관한 법률',
#     '법령명영문': 'FAIR TRANSACTIONS IN FRANCHISE BUSINESS ACT',
#     '법령ID': '009367',
#     '공포일자': '20220104',
#     '공포번호': '18709',
#     '제개정구분명': '일부개정',
#     '소관부처명': '공정거래위원회',
#     '법령구분명': '법률',
#     '시행일자': '20220705',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=238849&type=HTML&mobileYn='},
#    {'@id': '24',
#     '법령일련번호': '217715',
#     '현행연혁코드': '연혁',
#     '법령명한글': '가맹사업거래의 공정화에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE FAIR TRANSACTIONS IN FRANCHISE BUSINESS ACT',
#     '법령ID': '009369',
#     '공포일자': '20200428',
#     '공포번호': '30649',
#     '제개정구분명': '일부개정',
#     '소관부처명': '공정거래위원회',
#     '법령구분명': '대통령령',
#     '시행일자': '20200428',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=217715&type=HTML&mobileYn='},
#    {'@id': '25',
#     '법령일련번호': '232893',
#     '현행연혁코드': '현행',
#     '법령명한글': '가맹사업 진흥에 관한 법률',
#     '법령명영문': 'FRANCHISE BUSINESS PROMOTION ACT',
#     '법령ID': '010593',
#     '공포일자': '20210615',
#     '공포번호': '18267',
#     '제개정구분명': '일부개정',
#     '소관부처명': '산업통상자원부',
#     '법령구분명': '법률',
#     '시행일자': '20211216',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=232893&type=HTML&mobileYn='},
#    {'@id': '26',
#     '법령일련번호': '244033',
#     '현행연혁코드': '현행',
#     '법령명한글': '가맹사업 진흥에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE FRANCHISE BUSINESS PROMOTION ACT',
#     '법령ID': '010786',
#     '공포일자': '20220802',
#     '공포번호': '32838',
#     '제개정구분명': '일부개정',
#     '소관부처명': '산업통상자원부',
#     '법령구분명': '대통령령',
#     '시행일자': '20220802',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=244033&type=HTML&mobileYn='},
#    {'@id': '27',
#     '법령일련번호': '232959',
#     '현행연혁코드': '현행',
#     '법령명한글': '가사근로자의 고용개선 등에 관한 법률',
#     '법령명영문': 'ACT ON THE EMPLOYMENT IMPROVEMENT OF DOMESTIC WORKERS',
#     '법령ID': '014099',
#     '공포일자': '20210615',
#     '공포번호': '18285',
#     '제개정구분명': '제정',
#     '소관부처명': '고용노동부',
#     '법령구분명': '법률',
#     '시행일자': '20220616',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=232959&type=HTML&mobileYn='},
#    {'@id': '28',
#     '법령일련번호': '228887',
#     '현행연혁코드': '현행',
#     '법령명한글': '가사소송법',
#     '법령명영문': 'FAMILY LITIGATION ACT',
#     '법령ID': '001206',
#     '공포일자': '20210126',
#     '공포번호': '17905',
#     '제개정구분명': '타법개정',
#     '소관부처명': '법무부',
#     '법령구분명': '법률',
#     '시행일자': '20210126',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=228887&type=HTML&mobileYn='},
#    {'@id': '29',
#     '법령일련번호': '193683',
#     '현행연혁코드': '연혁',
#     '법령명한글': '가석방자관리규정',
#     '법령명영문': 'REGULATIONS ON THE SUPERVISION OF PAROLEES',
#     '법령ID': '002049',
#     '공포일자': '20170508',
#     '공포번호': '28016',
#     '제개정구분명': '일부개정',
#     '소관부처명': '법무부,법무부',
#     '법령구분명': '대통령령',
#     '시행일자': '20170508',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=193683&type=HTML&mobileYn='},
#    {'@id': '30',
#     '법령일련번호': '215909',
#     '현행연혁코드': '현행',
#     '법령명한글': '가습기살균제 피해구제를 위한 특별법',
#     '법령명영문': 'SPECIAL ACT ON REMEDY FOR DAMAGE CAUSED BY HUMIDIFIER DISINFECTANTS',
#     '법령ID': '012804',
#     '공포일자': '20200324',
#     '공포번호': '17102',
#     '제개정구분명': '일부개정',
#     '소관부처명': '환경부',
#     '법령구분명': '법률',
#     '시행일자': '20200925',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=215909&type=HTML&mobileYn='},
#    {'@id': '31',
#     '법령일련번호': '244087',
#     '현행연혁코드': '현행',
#     '법령명한글': '가습기살균제 피해구제를 위한 특별법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE SPECIAL ACT ON REMEDY FOR DAMAGE CAUSED BY HUMIDIFIER DISINFECTANTS',
#     '법령ID': '012969',
#     '공포일자': '20220802',
#     '공포번호': '32843',
#     '제개정구분명': '일부개정',
#     '소관부처명': '환경부',
#     '법령구분명': '대통령령',
#     '시행일자': '20220802',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=244087&type=HTML&mobileYn='},
#    {'@id': '32',
#     '법령일련번호': '772',
#     '현행연혁코드': '연혁',
#     '법령명한글': '가정의례에관한법률',
#     '법령명영문': 'FAMILY RITUAL STANDARDS ACT',
#     '법령ID': '000176',
#     '공포일자': '19971213',
#     '공포번호': '05454',
#     '제개정구분명': '타법개정',
#     '소관부처명': None,
#     '법령구분명': '법률',
#     '시행일자': '19980101',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=772&type=HTML&mobileYn='},
#    {'@id': '33',
#     '법령일련번호': '219133',
#     '현행연혁코드': '연혁',
#     '법령명한글': '가정폭력방지 및 피해자보호 등에 관한 법률',
#     '법령명영문': 'ACT ON THE PREVENTION OF DOMESTIC VIOLENCE AND PROTECTION, ETC. OF VICTIMS',
#     '법령ID': '000182',
#     '공포일자': '20200609',
#     '공포번호': '17437',
#     '제개정구분명': '일부개정',
#     '소관부처명': '여성가족부',
#     '법령구분명': '법률',
#     '시행일자': '20200609',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=219133&type=HTML&mobileYn='},
#    {'@id': '34',
#     '법령일련번호': '244277',
#     '현행연혁코드': '현행',
#     '법령명한글': '가정폭력방지 및 피해자보호 등에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE ACT ON THE PREVENTION OF DOMESTIC VIOLENCE AND PROTECTION OF VICTIMS',
#     '법령ID': '002053',
#     '공포일자': '20220816',
#     '공포번호': '32875',
#     '제개정구분명': '일부개정',
#     '소관부처명': '여성가족부,여성가족부',
#     '법령구분명': '대통령령',
#     '시행일자': '20220816',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=244277&type=HTML&mobileYn='},
#    {'@id': '35',
#     '법령일련번호': '245971',
#     '현행연혁코드': '현행',
#     '법령명한글': '가정폭력범죄의 처벌 등에 관한 특례법',
#     '법령명영문': 'ACT ON SPECIAL CASES CONCERNING THE PUNISHMENT OF CRIMES OF DOMESTIC VIOLENCE',
#     '법령ID': '001132',
#     '공포일자': '20221213',
#     '공포번호': '19068',
#     '제개정구분명': '일부개정',
#     '소관부처명': '법무부',
#     '법령구분명': '법률',
#     '시행일자': '20230614',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=245971&type=HTML&mobileYn='},
#    {'@id': '36',
#     '법령일련번호': '172201',
#     '현행연혁코드': '현행',
#     '법령명한글': '가정폭력범죄의 처벌 등에 관한 특례법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE ACT ON SPECIAL CASES CONCERNING THE PUNISHMENT, ETC. OF CRIMES OF DOMESTIC VIOLENCE',
#     '법령ID': '012308',
#     '공포일자': '20150622',
#     '공포번호': '26325',
#     '제개정구분명': '제정',
#     '소관부처명': '법무부',
#     '법령구분명': '대통령령',
#     '시행일자': '20150701',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=172201&type=HTML&mobileYn='},
#    {'@id': '37',
#     '법령일련번호': '230193',
#     '현행연혁코드': '연혁',
#     '법령명한글': '가족관계의 등록 등에 관한 법률',
#     '법령명영문': 'ACT ON REGISTRATION OF FAMILY RELATIONS',
#     '법령ID': '010444',
#     '공포일자': '20210316',
#     '공포번호': '17928',
#     '제개정구분명': '일부개정',
#     '소관부처명': '법무부',
#     '법령구분명': '법률',
#     '시행일자': '20210417',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=230193&type=HTML&mobileYn='},
#    {'@id': '38',
#     '법령일련번호': '219135',
#     '현행연혁코드': '현행',
#     '법령명한글': '가족친화 사회환경의 조성 촉진에 관한 법률',
#     '법령명영문': 'ACT ON THE PROMOTION OF CREATION OF FAMILY-FRIENDLY SOCIAL ENVIRONMENT',
#     '법령ID': '010583',
#     '공포일자': '20200609',
#     '공포번호': '17438',
#     '제개정구분명': '일부개정',
#     '소관부처명': '여성가족부',
#     '법령구분명': '법률',
#     '시행일자': '20201210',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=219135&type=HTML&mobileYn='},
#    {'@id': '39',
#     '법령일련번호': '195743',
#     '현행연혁코드': '연혁',
#     '법령명한글': '가족친화 사회환경의 조성 촉진에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE ACT ON THE PROMOTION OF CREATION OF FAMILY-FRIENDLY SOCIAL ENVIRONMENT',
#     '법령ID': '010770',
#     '공포일자': '20170726',
#     '공포번호': '28211',
#     '제개정구분명': '타법개정',
#     '소관부처명': '여성가족부',
#     '법령구분명': '대통령령',
#     '시행일자': '20170726',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=195743&type=HTML&mobileYn='},
#    {'@id': '40',
#     '법령일련번호': '218171',
#     '현행연혁코드': '연혁',
#     '법령명한글': '가축 및 축산물 이력관리에 관한 법률',
#     '법령명영문': 'CATTLE AND BEEF TRACEABILITY ACT',
#     '법령ID': '010599',
#     '공포일자': '20200526',
#     '공포번호': '17324',
#     '제개정구분명': '타법개정',
#     '소관부처명': '농림축산식품부',
#     '법령구분명': '법률',
#     '시행일자': '20201127',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=218171&type=HTML&mobileYn='},
#    {'@id': '41',
#     '법령일련번호': '231457',
#     '현행연혁코드': '현행',
#     '법령명한글': '가축분뇨의 관리 및 이용에 관한 법률',
#     '법령명영문': 'ACT ON THE MANAGEMENT AND USE OF LIVESTOCK EXCRETA',
#     '법령ID': '010297',
#     '공포일자': '20210413',
#     '공포번호': '18027',
#     '제개정구분명': '일부개정',
#     '소관부처명': '환경부',
#     '법령구분명': '법률',
#     '시행일자': '20211014',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=231457&type=HTML&mobileYn='},
#    {'@id': '42',
#     '법령일련번호': '236951',
#     '현행연혁코드': '현행',
#     '법령명한글': '가축전염병 예방법',
#     '법령명영문': 'ACT ON THE PREVENTION OF CONTAGIOUS ANIMAL DISEASES',
#     '법령ID': '001504',
#     '공포일자': '20211130',
#     '공포번호': '18524',
#     '제개정구분명': '일부개정',
#     '소관부처명': '농림축산식품부,농림축산식품부,농림축산식품부',
#     '법령구분명': '법률',
#     '시행일자': '20211130',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=236951&type=HTML&mobileYn='},
#    {'@id': '43',
#     '법령일련번호': '235885',
#     '현행연혁코드': '연혁',
#     '법령명한글': '가축전염병 예방법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE ACT ON THE PREVENTION OF CONTAGIOUS ANIMAL DISEASES',
#     '법령ID': '002058',
#     '공포일자': '20211005',
#     '공포번호': '32023',
#     '제개정구분명': '일부개정',
#     '소관부처명': '농림축산식품부,농림축산식품부,농림축산식품부',
#     '법령구분명': '대통령령',
#     '시행일자': '20211014',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=235885&type=HTML&mobileYn='},
#    {'@id': '44',
#     '법령일련번호': '199765',
#     '현행연혁코드': '연혁',
#     '법령명한글': '각급 법원의 설치와 관할구역에 관한 법률',
#     '법령명영문': 'ACT ON THE ESTABLISHMENT AND JURISDICTION OF COURTS OF VARIOUS LEVELS',
#     '법령ID': '001709',
#     '공포일자': '20171219',
#     '공포번호': '15248',
#     '제개정구분명': '일부개정',
#     '소관부처명': '대법원',
#     '법령구분명': '법률',
#     '시행일자': '20171219',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=199765&type=HTML&mobileYn='},
#    {'@id': '45',
#     '법령일련번호': '166366',
#     '현행연혁코드': '현행',
#     '법령명한글': '각급 법원 판사 정원법',
#     '법령명영문': 'ACT ON THE PRESCRIBED NUMBER OF JUDGES OF VARIOUS LEVELS OF COURTS',
#     '법령ID': '001300',
#     '공포일자': '20141231',
#     '공포번호': '12951',
#     '제개정구분명': '일부개정',
#     '소관부처명': '대법원',
#     '법령구분명': '법률',
#     '시행일자': '20141231',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=166366&type=HTML&mobileYn='},
#    {'@id': '46',
#     '법령일련번호': '243069',
#     '현행연혁코드': '연혁',
#     '법령명한글': '간선급행버스체계의 건설 및 운영에 관한 특별법',
#     '법령명영문': 'SPECIAL ACT ON THE CONSTRUCTION AND OPERATION OF BUS RAPID TRANSIT SYSTEM',
#     '법령ID': '012071',
#     '공포일자': '20220610',
#     '공포번호': '18931',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부',
#     '법령구분명': '법률',
#     '시행일자': '20221211',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=243069&type=HTML&mobileYn='},
#    {'@id': '47',
#     '법령일련번호': '84533',
#     '현행연혁코드': '연혁',
#     '법령명한글': '간접투자자산 운용업법',
#     '법령명영문': 'INDIRECT INVESTMENT ASSET MANAGEMENT BUSINESS ACT',
#     '법령ID': '009559',
#     '공포일자': '20080314',
#     '공포번호': '08910',
#     '제개정구분명': '일부개정',
#     '소관부처명': '금융위원회,기획재정부',
#     '법령구분명': '법률',
#     '시행일자': '20080314',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=84533&type=HTML&mobileYn='},
#    {'@id': '48',
#     '법령일련번호': '86822',
#     '현행연혁코드': '연혁',
#     '법령명한글': '간접투자자산 운용업법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE INDIRECT INVESTMENT ASSET MANAGEMENT BUSINESS ACT',
#     '법령ID': '009661',
#     '공포일자': '20080229',
#     '공포번호': '20653',
#     '제개정구분명': '타법개정',
#     '소관부처명': '금융위원회,행정안전부',
#     '법령구분명': '대통령령',
#     '시행일자': '20080229',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=86822&type=HTML&mobileYn='},
#    {'@id': '49',
#     '법령일련번호': '84098',
#     '현행연혁코드': '연혁',
#     '법령명한글': '간접투자자산 운용업법 시행규칙',
#     '법령명영문': 'ENFORCEMENT RULE OF THE INDIRECT INVESTMENT ASSET MANAGEMENT BUSINESS ACT',
#     '법령ID': '009690',
#     '공포일자': '20080303',
#     '공포번호': '00875',
#     '제개정구분명': '타법개정',
#     '소관부처명': '금융위원회',
#     '법령구분명': '총리령',
#     '시행일자': '20080303',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=84098&type=HTML&mobileYn='},
#    {'@id': '50',
#     '법령일련번호': '238829',
#     '현행연혁코드': '연혁',
#     '법령명한글': '간척지의 농어업적 이용 및 관리에 관한 법률',
#     '법령명영문': 'ACT ON THE USE AND MANAGEMENT OF RECLAIMED LAND FOR AGRICULTURE AND FISHERIES',
#     '법령ID': '011522',
#     '공포일자': '20220104',
#     '공포번호': '18687',
#     '제개정구분명': '일부개정',
#     '소관부처명': '농림축산식품부',
#     '법령구분명': '법률',
#     '시행일자': '20220705',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=238829&type=HTML&mobileYn='},
#    {'@id': '51',
#     '법령일련번호': '222549',
#     '현행연혁코드': '현행',
#     '법령명한글': '감사원법',
#     '법령명영문': 'BOARD OF AUDIT AND INSPECTION ACT',
#     '법령ID': '001372',
#     '공포일자': '20201020',
#     '공포번호': '17560',
#     '제개정구분명': '일부개정',
#     '소관부처명': '감사원',
#     '법령구분명': '법률',
#     '시행일자': '20201020',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=222549&type=HTML&mobileYn='},
#    {'@id': '52',
#     '법령일련번호': '249297',
#     '현행연혁코드': '시행예정',
#     '법령명한글': '감염병의 예방 및 관리에 관한 법률',
#     '법령명영문': 'INFECTIOUS DISEASE CONTROL AND PREVENTION ACT',
#     '법령ID': '001792',
#     '공포일자': '20230328',
#     '공포번호': '19290',
#     '제개정구분명': '일부개정',
#     '소관부처명': '질병관리청,질병관리청,질병관리청,질병관리청,질병관리청,보건복지부',
#     '법령구분명': '법률',
#     '시행일자': '20230929',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=249297&type=HTML&mobileYn='},
#    {'@id': '53',
#     '법령일련번호': '239753',
#     '현행연혁코드': '연혁',
#     '법령명한글': '감염병의 예방 및 관리에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE INFECTIOUS DISEASE CONTROL AND PREVENTION ACT',
#     '법령ID': '004750',
#     '공포일자': '20220125',
#     '공포번호': '32365',
#     '제개정구분명': '일부개정',
#     '소관부처명': '질병관리청,질병관리청,질병관리청,질병관리청,질병관리청,보건복지부',
#     '법령구분명': '대통령령',
#     '시행일자': '20220125',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=239753&type=HTML&mobileYn='},
#    {'@id': '54',
#     '법령일련번호': '234029',
#     '현행연혁코드': '연혁',
#     '법령명한글': '감정평가 및 감정평가사에 관한 법률',
#     '법령명영문': 'ACT ON APPRAISAL AND CERTIFIED APPRAISERS',
#     '법령ID': '012481',
#     '공포일자': '20210720',
#     '공포번호': '18309',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부,국토교통부',
#     '법령구분명': '법률',
#     '시행일자': '20220121',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=234029&type=HTML&mobileYn='},
#    {'@id': '55',
#     '법령일련번호': '200201',
#     '현행연혁코드': '연혁',
#     '법령명한글': '개발이익 환수에 관한 법률',
#     '법령명영문': 'RESTITUTION OF DEVELOPMENT GAINS ACT',
#     '법령ID': '001829',
#     '공포일자': '20171226',
#     '공포번호': '15305',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부',
#     '법령구분명': '법률',
#     '시행일자': '20180627',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=200201&type=HTML&mobileYn='},
#    {'@id': '56',
#     '법령일련번호': '234247',
#     '현행연혁코드': '연혁',
#     '법령명한글': '개발이익 환수에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE RESTITUTION OF DEVELOPMENT GAINS ACT',
#     '법령ID': '002088',
#     '공포일자': '20210727',
#     '공포번호': '31918',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부',
#     '법령구분명': '대통령령',
#     '시행일자': '20210727',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=234247&type=HTML&mobileYn='},
#    {'@id': '57',
#     '법령일련번호': '243071',
#     '현행연혁코드': '연혁',
#     '법령명한글': '개발제한구역의 지정 및 관리에 관한 특별조치법',
#     '법령명영문': 'ACT ON SPECIAL MEASURES FOR DESIGNATION AND MANAGEMENT OF DEVELOPMENT RESTRICTION ZONES',
#     '법령ID': '002018',
#     '공포일자': '20220610',
#     '공포번호': '18932',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부,국토교통부,국토교통부,국토교통부',
#     '법령구분명': '법률',
#     '시행일자': '20221211',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=243071&type=HTML&mobileYn='},
#    {'@id': '58',
#     '법령일련번호': '232103',
#     '현행연혁코드': '연혁',
#     '법령명한글': '개발제한구역의 지정 및 관리에 관한 특별조치법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE ACT ON SPECIAL MEASURES FOR DESIGNATION AND MANAGEMENT OF DEVELOPMENT RESTRICTION ZONES',
#     '법령ID': '002089',
#     '공포일자': '20210511',
#     '공포번호': '31683',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부,국토교통부,국토교통부,국토교통부',
#     '법령구분명': '대통령령',
#     '시행일자': '20210511',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=232103&type=HTML&mobileYn='},
#    {'@id': '59',
#     '법령일련번호': '238001',
#     '현행연혁코드': '연혁',
#     '법령명한글': '개별소비세법',
#     '법령명영문': 'INDIVIDUAL CONSUMPTION TAX ACT',
#     '법령ID': '001570',
#     '공포일자': '20211221',
#     '공포번호': '18582',
#     '제개정구분명': '일부개정',
#     '소관부처명': '기획재정부',
#     '법령구분명': '법률',
#     '시행일자': '20220101',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=238001&type=HTML&mobileYn='},
#    {'@id': '60',
#     '법령일련번호': '219781',
#     '현행연혁코드': '연혁',
#     '법령명한글': '개별소비세법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE INDIVIDUAL CONSUMPTION TAX ACT',
#     '법령ID': '005308',
#     '공포일자': '20200630',
#     '공포번호': '30805',
#     '제개정구분명': '일부개정',
#     '소관부처명': '기획재정부',
#     '법령구분명': '대통령령',
#     '시행일자': '20200701',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=219781&type=HTML&mobileYn='},
#    {'@id': '61',
#     '법령일련번호': '206402',
#     '현행연혁코드': '연혁',
#     '법령명한글': '개성공업지구 지원에 관한 법률',
#     '법령명영문': 'ACT ON SUPPORT FOR GAESEONG INDUSTRIAL COMPLEX',
#     '법령ID': '010451',
#     '공포일자': '20181231',
#     '공포번호': '16172',
#     '제개정구분명': '타법개정',
#     '소관부처명': '통일부',
#     '법령구분명': '법률',
#     '시행일자': '20190401',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=206402&type=HTML&mobileYn='},
#    {'@id': '62',
#     '법령일련번호': '240461',
#     '현행연혁코드': '연혁',
#     '법령명한글': '개성공업지구 지원에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE ACT ON SUPPORT FOR GAESEONG INDUSTRIAL COMPLEX',
#     '법령ID': '010523',
#     '공포일자': '20220217',
#     '공포번호': '32447',
#     '제개정구분명': '타법개정',
#     '소관부처명': '통일부',
#     '법령구분명': '대통령령',
#     '시행일자': '20220218',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=240461&type=HTML&mobileYn='},
#    {'@id': '63',
#     '법령일련번호': '115382',
#     '현행연혁코드': '연혁',
#     '법령명한글': '개성공업지구 지원에 관한 법률 시행규칙',
#     '법령명영문': 'Enforcement Regulations of the Gaeseong Industrial Complex Support Act',
#     '법령ID': '011438',
#     '공포일자': '20110726',
#     '공포번호': '00063',
#     '제개정구분명': '제정',
#     '소관부처명': '통일부',
#     '법령구분명': '통일부령',
#     '시행일자': '20110726',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=115382&type=HTML&mobileYn='},
#    {'@id': '64',
#     '법령일련번호': '213857',
#     '현행연혁코드': '연혁',
#     '법령명한글': '개인정보 보호법',
#     '법령명영문': 'PERSONAL INFORMATION PROTECTION ACT',
#     '법령ID': '011357',
#     '공포일자': '20200204',
#     '공포번호': '16930',
#     '제개정구분명': '일부개정',
#     '소관부처명': '개인정보보호위원회,개인정보보호위원회',
#     '법령구분명': '법률',
#     '시행일자': '20200805',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=213857&type=HTML&mobileYn='},
#    {'@id': '65',
#     '법령일련번호': '243935',
#     '현행연혁코드': '연혁',
#     '법령명한글': '개인정보 보호법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE PERSONAL INFORMATION PROTECTION ACT',
#     '법령ID': '011468',
#     '공포일자': '20220719',
#     '공포번호': '32813',
#     '제개정구분명': '일부개정',
#     '소관부처명': '개인정보보호위원회,개인정보보호위원회',
#     '법령구분명': '대통령령',
#     '시행일자': '20221020',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=243935&type=HTML&mobileYn='},
#    {'@id': '66',
#     '법령일련번호': '137979',
#     '현행연혁코드': '연혁',
#     '법령명한글': '개인정보 보호법 시행규칙',
#     '법령명영문': 'Enforcement Rules to Personal Information Protection Act',
#     '법령ID': '011471',
#     '공포일자': '20130323',
#     '공포번호': '00001',
#     '제개정구분명': '타법개정',
#     '소관부처명': '개인정보보호위원회',
#     '법령구분명': '안전행정부령',
#     '시행일자': '20130323',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=137979&type=HTML&mobileYn='},
#    {'@id': '67',
#     '법령일련번호': '137110',
#     '현행연혁코드': '연혁',
#     '법령명한글': '개항질서법',
#     '법령명영문': 'PUBLIC ORDER IN OPEN PORTS ACT',
#     '법령ID': '000057',
#     '공포일자': '20130323',
#     '공포번호': '11690',
#     '제개정구분명': '타법개정',
#     '소관부처명': '해양수산부',
#     '법령구분명': '법률',
#     '시행일자': '20130323',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=137110&type=HTML&mobileYn='},
#    {'@id': '68',
#     '법령일련번호': '214577',
#     '현행연혁코드': '연혁',
#     '법령명한글': '갯벌 및 그 주변지역의 지속가능한 관리와 복원에 관한 법률',
#     '법령명영문': 'ACT ON THE SUSTAINABLE MANAGEMENT AND RESTORATION OF TIDAL FLATS (GAETBEOL) AND ADJACENT AREAS THEREOF',
#     '법령ID': '013246',
#     '공포일자': '20200218',
#     '공포번호': '17063',
#     '제개정구분명': '타법개정',
#     '소관부처명': '해양수산부',
#     '법령구분명': '법률',
#     '시행일자': '20210219',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=214577&type=HTML&mobileYn='},
#    {'@id': '69',
#     '법령일련번호': '213221',
#     '현행연혁코드': '연혁',
#     '법령명한글': '갯벌 및 그 주변지역의 지속가능한 관리와 복원에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE ACT ON THE SUSTAINABLE MANAGEMENT AND RESTORATION OF TIDAL FLATS (GAETBEOL) AND ADJACENT AREAS THEREOF',
#     '법령ID': '013647',
#     '공포일자': '20200107',
#     '공포번호': '30340',
#     '제개정구분명': '제정',
#     '소관부처명': '해양수산부',
#     '법령구분명': '대통령령',
#     '시행일자': '20200116',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=213221&type=HTML&mobileYn='},
#    {'@id': '70',
#     '법령일련번호': '116110',
#     '현행연혁코드': '현행',
#     '법령명한글': '거절증서령',
#     '법령명영문': 'DECREE ON CERTIFICATES OF PROTEST',
#     '법령ID': '002096',
#     '공포일자': '20110819',
#     '공포번호': '23077',
#     '제개정구분명': '일부개정',
#     '소관부처명': '법무부',
#     '법령구분명': '대통령령',
#     '시행일자': '20110819',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=116110&type=HTML&mobileYn='},
#    {'@id': '71',
#     '법령일련번호': '149559',
#     '현행연혁코드': '현행',
#     '법령명한글': '거창사건등 관련자의 명예회복에 관한 특별조치법',
#     '법령명영문': 'ACT ON SPECIAL MEASURES FOR THE RESTORATION OF HONOR OF THE PERSONS INVOLVED IN THE GEOCHANG INCIDENT',
#     '법령ID': '001177',
#     '공포일자': '20140107',
#     '공포번호': '12200',
#     '제개정구분명': '일부개정',
#     '소관부처명': '행정안전부,국방부',
#     '법령구분명': '법률',
#     '시행일자': '20140107',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=149559&type=HTML&mobileYn='},
#    {'@id': '72',
#     '법령일련번호': '218015',
#     '현행연혁코드': '현행',
#     '법령명한글': '건강가정기본법',
#     '법령명영문': 'FRAMEWORK ACT ON HEALTHY HOMES',
#     '법령ID': '009682',
#     '공포일자': '20200519',
#     '공포번호': '17280',
#     '제개정구분명': '일부개정',
#     '소관부처명': '여성가족부',
#     '법령구분명': '법률',
#     '시행일자': '20200519',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=218015&type=HTML&mobileYn='},
#    {'@id': '73',
#     '법령일련번호': '205610',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건강검진기본법',
#     '법령명영문': 'FRAMEWORK ACT ON HEALTH EXAMINATIONS',
#     '법령ID': '010708',
#     '공포일자': '20181211',
#     '공포번호': '15870',
#     '제개정구분명': '일부개정',
#     '소관부처명': '보건복지부',
#     '법령구분명': '법률',
#     '시행일자': '20181211',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=205610&type=HTML&mobileYn='},
#    {'@id': '74',
#     '법령일련번호': '207845',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건강검진기본법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE FRAMEWORK ACT ON HEALTH EXAMINATIONS',
#     '법령ID': '010930',
#     '공포일자': '20190219',
#     '공포번호': '29556',
#     '제개정구분명': '일부개정',
#     '소관부처명': '보건복지부',
#     '법령구분명': '대통령령',
#     '시행일자': '20190219',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=207845&type=HTML&mobileYn='},
#    {'@id': '75',
#     '법령일련번호': '234347',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건강기능식품에 관한 법률',
#     '법령명영문': 'HEALTH FUNCTIONAL FOODS ACT',
#     '법령ID': '009353',
#     '공포일자': '20210727',
#     '공포번호': '18359',
#     '제개정구분명': '일부개정',
#     '소관부처명': '식품의약품안전처',
#     '법령구분명': '법률',
#     '시행일자': '20210727',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=234347&type=HTML&mobileYn='},
#    {'@id': '76',
#     '법령일련번호': '243887',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건강기능식품에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE HEALTH FUNCTIONAL FOODS ACT',
#     '법령ID': '009581',
#     '공포일자': '20220719',
#     '공포번호': '32815',
#     '제개정구분명': '일부개정',
#     '소관부처명': '식품의약품안전처',
#     '법령구분명': '대통령령',
#     '시행일자': '20220728',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=243887&type=HTML&mobileYn='},
#    {'@id': '77',
#     '법령일련번호': '211759',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건설근로자의 고용개선 등에 관한 법률',
#     '법령명영문': 'ACT ON THE EMPLOYMENT IMPROVEMENT, ETC. OF CONSTRUCTION WORKERS',
#     '법령ID': '000120',
#     '공포일자': '20191126',
#     '공포번호': '16620',
#     '제개정구분명': '일부개정',
#     '소관부처명': '고용노동부',
#     '법령구분명': '법률',
#     '시행일자': '20200527',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=211759&type=HTML&mobileYn='},
#    {'@id': '78',
#     '법령일련번호': '232145',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건설근로자의 고용개선 등에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE ACT ON THE EMPLOYMENT IMPROVEMENT OF CONSTRUCTION WORKERS',
#     '법령ID': '002108',
#     '공포일자': '20210518',
#     '공포번호': '31692',
#     '제개정구분명': '일부개정',
#     '소관부처명': '고용노동부',
#     '법령구분명': '대통령령',
#     '시행일자': '20210527',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=232145&type=HTML&mobileYn='},
#    {'@id': '79',
#     '법령일련번호': '239987',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건설기계관리법',
#     '법령명영문': 'CONSTRUCTION MACHINERY MANAGEMENT ACT',
#     '법령ID': '000239',
#     '공포일자': '20220203',
#     '공포번호': '18822',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부',
#     '법령구분명': '법률',
#     '시행일자': '20220804',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=239987&type=HTML&mobileYn='},
#    {'@id': '80',
#     '법령일련번호': '244095',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건설기계관리법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE CONSTRUCTION MACHINERY MANAGEMENT ACT',
#     '법령ID': '002109',
#     '공포일자': '20220802',
#     '공포번호': '32848',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부',
#     '법령구분명': '대통령령',
#     '시행일자': '20220804',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=244095&type=HTML&mobileYn='},
#    {'@id': '81',
#     '법령일련번호': '71769',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건설기계저당법',
#     '법령명영문': 'CONSTRUCTION MACHINERY MORTGAGE ACT',
#     '법령ID': '001252',
#     '공포일자': '20051108',
#     '공포번호': '07694',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부',
#     '법령구분명': '법률',
#     '시행일자': '20051108',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=71769&type=HTML&mobileYn='},
#    {'@id': '82',
#     '법령일련번호': '61624',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건설기계저당법시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE CONSTRUCTION MACHINERY MORTGAGE ACT',
#     '법령ID': '002110',
#     '공포일자': '20040317',
#     '공포번호': '18312',
#     '제개정구분명': '타법개정',
#     '소관부처명': '국토교통부',
#     '법령구분명': '대통령령',
#     '시행일자': '20040317',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=61624&type=HTML&mobileYn='},
#    {'@id': '83',
#     '법령일련번호': '243073',
#     '현행연혁코드': '현행',
#     '법령명한글': '건설기술 진흥법',
#     '법령명영문': 'CONSTRUCTION TECHNOLOGY PROMOTION ACT',
#     '법령ID': '001807',
#     '공포일자': '20220610',
#     '공포번호': '18933',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부',
#     '법령구분명': '법률',
#     '시행일자': '20220610',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=243073&type=HTML&mobileYn='},
#    {'@id': '84',
#     '법령일련번호': '244571',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건설기술 진흥법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE CONSTRUCTION TECHNOLOGY PROMOTION ACT',
#     '법령ID': '002111',
#     '공포일자': '20220913',
#     '공포번호': '32906',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부',
#     '법령구분명': '대통령령',
#     '시행일자': '20220913',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=244571&type=HTML&mobileYn='},
#    {'@id': '85',
#     '법령일련번호': '204760',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건설기술 진흥법 시행규칙',
#     '법령명영문': 'ENFORCEMENT RULE OF THE CONSTRUCTION TECHNOLOGY PROMOTION ACT',
#     '법령ID': '006175',
#     '공포일자': '20181012',
#     '공포번호': '00547',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부',
#     '법령구분명': '국토교통부령',
#     '시행일자': '20181012',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=204760&type=HTML&mobileYn='},
#    {'@id': '86',
#     '법령일련번호': '224335',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건설산업기본법',
#     '법령명영문': 'FRAMEWORK ACT ON THE CONSTRUCTION INDUSTRY',
#     '법령ID': '001808',
#     '공포일자': '20201222',
#     '공포번호': '17653',
#     '제개정구분명': '타법개정',
#     '소관부처명': '국토교통부,국토교통부,국토교통부,국토교통부',
#     '법령구분명': '법률',
#     '시행일자': '20210101',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=224335&type=HTML&mobileYn='},
#    {'@id': '87',
#     '법령일련번호': '243927',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건설산업기본법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE FRAMEWORK ACT ON THE CONSTRUCTION INDUSTRY',
#     '법령ID': '002115',
#     '공포일자': '20220719',
#     '공포번호': '32809',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부,국토교통부,국토교통부,국토교통부',
#     '법령구분명': '대통령령',
#     '시행일자': '20220804',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=243927&type=HTML&mobileYn='},
#    {'@id': '88',
#     '법령일련번호': '208367',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건설폐기물의 재활용촉진에 관한 법률',
#     '법령명영문': 'CONSTRUCTION WASTE RECYCLING PROMOTION ACT',
#     '법령ID': '009592',
#     '공포일자': '20190416',
#     '공포번호': '16317',
#     '제개정구분명': '일부개정',
#     '소관부처명': '환경부',
#     '법령구분명': '법률',
#     '시행일자': '20200417',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=208367&type=HTML&mobileYn='},
#    {'@id': '89',
#     '법령일련번호': '230821',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건설폐기물의 재활용촉진에 관한 법률 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE CONSTRUCTION WASTE RECYCLING PROMOTION ACT',
#     '법령ID': '009857',
#     '공포일자': '20210406',
#     '공포번호': '31606',
#     '제개정구분명': '일부개정',
#     '소관부처명': '환경부',
#     '법령구분명': '대통령령',
#     '시행일자': '20210417',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=230821&type=HTML&mobileYn='},
#    {'@id': '90',
#     '법령일련번호': '122701',
#     '현행연혁코드': '현행',
#     '법령명한글': '건전가정의례의 정착 및 지원에 관한 법률',
#     '법령명영문': 'ACT ON FAMILY RITE ESTABLISHMENT AND RELATED ASSISTANCE',
#     '법령ID': '001962',
#     '공포일자': '20120201',
#     '공포번호': '11282',
#     '제개정구분명': '일부개정',
#     '소관부처명': '여성가족부',
#     '법령구분명': '법률',
#     '시행일자': '20120201',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=122701&type=HTML&mobileYn='},
#    {'@id': '91',
#     '법령일련번호': '195220',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건축기본법',
#     '법령명영문': 'FRAMEWORK ACT ON BUILDING',
#     '법령ID': '010594',
#     '공포일자': '20170726',
#     '공포번호': '14839',
#     '제개정구분명': '타법개정',
#     '소관부처명': '국토교통부',
#     '법령구분명': '법률',
#     '시행일자': '20170726',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=195220&type=HTML&mobileYn='},
#    {'@id': '92',
#     '법령일련번호': '210183',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건축물의 분양에 관한 법률',
#     '법령명영문': 'ACT ON SALE OF BUILDING UNITS',
#     '법령ID': '009760',
#     '공포일자': '20190820',
#     '공포번호': '16484',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부',
#     '법령구분명': '법률',
#     '시행일자': '20200221',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=210183&type=HTML&mobileYn='},
#    {'@id': '93',
#     '법령일련번호': '245335',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건축법',
#     '법령명영문': 'BUILDING ACT',
#     '법령ID': '001823',
#     '공포일자': '20221115',
#     '공포번호': '19045',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부',
#     '법령구분명': '법률',
#     '시행일자': '20230516',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=245335&type=HTML&mobileYn='},
#    {'@id': '94',
#     '법령일련번호': '242001',
#     '현행연혁코드': '연혁',
#     '법령명한글': '건축법 시행령',
#     '법령명영문': 'ENFORCEMENT DECREE OF THE BUILDING ACT',
#     '법령ID': '002118',
#     '공포일자': '20220429',
#     '공포번호': '32614',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부,국토교통부,국토교통부,국토교통부,국토교통부,국토교통부',
#     '법령구분명': '대통령령',
#     '시행일자': '20220429',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=242001&type=HTML&mobileYn='},
#    {'@id': '95',
#     '법령일련번호': '240077',
#     '현행연혁코드': '현행',
#     '법령명한글': '건축사법',
#     '법령명영문': 'CERTIFIED ARCHITECTS ACT',
#     '법령ID': '000254',
#     '공포일자': '20220203',
#     '공포번호': '18826',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부',
#     '법령구분명': '법률',
#     '시행일자': '20220804',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=240077&type=HTML&mobileYn='},
#    {'@id': '96',
#     '법령일련번호': '245343',
#     '현행연혁코드': '현행',
#     '법령명한글': '건축서비스산업 진흥법',
#     '법령명영문': 'ACT ON THE PROMOTION OF BUILDING SERVICE INDUSTRY',
#     '법령ID': '011868',
#     '공포일자': '20221115',
#     '공포번호': '19046',
#     '제개정구분명': '일부개정',
#     '소관부처명': '국토교통부',
#     '법령구분명': '법률',
#     '시행일자': '20221115',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=245343&type=HTML&mobileYn='},
#    {'@id': '97',
#     '법령일련번호': '121947',
#     '현행연혁코드': '현행',
#     '법령명한글': '검사의 보수에 관한 법률',
#     '법령명영문': 'REMUNERATION OF PUBLIC PROSECUTORS ACT',
#     '법령ID': '001282',
#     '공포일자': '20120117',
#     '공포번호': '11152',
#     '제개정구분명': '일부개정',
#     '소관부처명': '법무부',
#     '법령구분명': '법률',
#     '시행일자': '20120117',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=121947&type=HTML&mobileYn='},
#    {'@id': '98',
#     '법령일련번호': '166367',
#     '현행연혁코드': '현행',
#     '법령명한글': '검사정원법',
#     '법령명영문': 'PROSECUTORS QUOTA ACT',
#     '법령ID': '001284',
#     '공포일자': '20141231',
#     '공포번호': '12952',
#     '제개정구분명': '일부개정',
#     '소관부처명': '법무부',
#     '법령구분명': '법률',
#     '시행일자': '20141231',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=166367&type=HTML&mobileYn='},
#    {'@id': '99',
#     '법령일련번호': '238789',
#     '현행연혁코드': '현행',
#     '법령명한글': '검사징계법',
#     '법령명영문': 'ACT ON DISCIPLINE OF PROSECUTORS',
#     '법령ID': '001281',
#     '공포일자': '20220104',
#     '공포번호': '18668',
#     '제개정구분명': '일부개정',
#     '소관부처명': '법무부',
#     '법령구분명': '법률',
#     '시행일자': '20220104',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=238789&type=HTML&mobileYn='},
#    {'@id': '100',
#     '법령일련번호': '237891',
#     '현행연혁코드': '현행',
#     '법령명한글': '검역법',
#     '법령명영문': 'QUARANTINE ACT',
#     '법령ID': '001790',
#     '공포일자': '20211221',
#     '공포번호': '18604',
#     '제개정구분명': '일부개정',
#     '소관부처명': '질병관리청',
#     '법령구분명': '법률',
#     '시행일자': '20220622',
#     '자법타법여부': None,
#     '법령상세링크': '/DRF/lawService.do?OC=nellcome4636&target=elaw&MST=237891&type=HTML&mobileYn='}]}}

# %%
# keys: '@id', '법령일련번호', '현행연혁코드', '법령명한글', '법령명영문', '법령ID', '공포일자', '공포번호', '제개정구분명', '소관부처명', '법령구분명', '시행일자', '자법타법여부', '법령상세링크'
for law in json_data['LawSearch']['law'][1:2]:
    mst = law['법령일련번호']
    url = f'http://www.law.go.kr/DRF/lawService.do?target=elaw&OC={OC}&MST={mst}'
    json_data_en = xmltodict.parse(requests.get(url).text)
    url = f'http://www.law.go.kr/DRF/lawService.do?target=law&OC={OC}&MST={mst}'
    json_data_kr = xmltodict.parse(requests.get(url).text)
    # print(law['법령상세링크'], law['법령일련번호'])

# %%
json_data_kr.keys()
# Out:
# dict_keys(['법령'])

# %%
print("en", json_data_en['Law'].keys())
print("kr", json_data_kr['법령'].keys())
# Out:
# en dict_keys(['InfSection', 'JoSection', 'ArSection', 'BylSection'])
# kr dict_keys(['@법령키', '기본정보', '조문', '부칙', '별표', '개정문', '제개정이유'])

# %%
json_data_en['Law']['InfSection'].keys(), json_data_kr['법령']['기본정보'].keys()
# Out:
# (dict_keys(['lsId', 'ancYd', 'ancNo', 'lsNmEng', 'lsHwpFl']),
#  dict_keys(['법령ID', '공포일자', '공포번호', '언어', '법종구분', '법령명_한글', '법령명_한자', '법령명약칭', '제명변경여부', '한글법령여부', '편장절관', '소관부처', '전화번호', '시행일자', '제개정구분', '별표시행일자문자열', '별표편집여부', '공포법령여부', '연락부서']))

# %%
len(json_data_en['Law']['JoSection']['Jo']), len(json_data_kr['법령']['조문']['조문단위'])
# Out:
# (47, 47)

# %%
# Cts: 내용
#

# %%
json_data_en['Law']['JoSection'].keys()

# %% [markdown]
# * ```joNo```: 조문번호 (en:4자리, kr:정수) > ex. 0016 / 16
# * joBrNo: 조문가지번호
# 25-2조: 25: 조문번호, 2: 조문가지번호
# * ```joTtl```: 조문제목
# * ```joCts```: 조문내용
#     * en: ```\n```로 구분되어 있음
#     * kr: key로 구분되어 있음
#     * (1) : ①
#     * 1 : 1

# %% [markdown]
# **조문내용 관련**
# * 검증: 조문의 총 개수에 대한 비고
#
# ```python
# len(json_data_en['Law']['JoSection']['Jo']), len(json_data_kr['법령']['조문']['조문단위'])
# ```
#
#
# * 검증: 조문참고자료가 있을 경우 en에서 '\n'으로 split하고 마지막 제외로 개수세기
#
#
# ```python
# len(json_data_en['Law']['JoSection']['Jo'][{index}]['joCts'].split('\n')) - (1 if '조문참고자료' in json_data_kr['법령']['조문']['조문단위'][{index}] else 0), sum([len(t['호'])+1 if '호' in t else 1 for t in json_data_kr['법령']['조문']['조문단위'][31]['항']])
# ```

# %%
json_data_kr['법령']['조문']['조문단위'][31]

# %%
json_data_kr['법령']['조문']['조문단위'][31]['항'], json_data_en['Law']['JoSection']['Jo'][31]['joCts'].split('\n')

# %%
len(json_data_en['Law']['JoSection']['Jo'][31]['joCts'].split('\n')) - (1 if '조문참고자료' in json_data_kr['법령']['조문']['조문단위'][31] else 0), sum([len(t['호'])+1 if '호' in t else 1 for t in json_data_kr['법령']['조문']['조문단위'][31]['항']])

# %%
len(json_data_en['Law']['ArSection']['Ar']), len(json_data_kr['법령']['부칙']['부칙단위'])

# %%
json_data_en['Law']['JoSection']

# %%
len(json_data_en['Law']['ArSection']['Ar']), json_data_kr['법령']['부칙']['부칙단위'][0]

# %%
import xmltodict
import json

# 한글이 포함된 XML 데이터 예시
xml_data = '''<root>
    <person>
        <name>홍길동</name>
        <age>30</age>
    </person>
    <person>
        <name>이순신</name>
        <age>25</age>
    </person>
</root>'''

# XML을 파싱하여 JSON으로 변환
json_data = json.dumps(xmltodict.parse(xml_data), indent=4, ensure_ascii=False)

# JSON 데이터 출력
print(json_data)

# %% [markdown]
# # 데이터 불러오기 (코드 정리)

# %%
list_url = f'http://www.law.go.kr/DRF/lawSearch.do?OC={OC}&target=elaw&page={30}&display=100'
response = requests.get(list_url)
json_data = xmltodict.parse(response.text)

# %%
response
# Out:
# <Response [200]>

# %%
json_data['LawSearch'].keys()
# Out:
# dict_keys(['target', '키워드', 'section', 'totalCnt', 'page'])

# %% [markdown]
# ## 법령 일련번호(MST) 가져오기

# %%
# 데이터 개수 en: 2586 kr: 5273
# 예상페이지 수: 26page (2586 // 100)
# 예상페이지 수: 53page (5273 // 100)

# MST(일련번호) 모두 가져오기
en_mst = set()
kr_mst = set()

for page in tqdm(range(1,30)):
    # print(page, "/ 26")
    list_url = f'http://www.law.go.kr/DRF/lawSearch.do?OC={OC}&target=elaw&page={page}&display=100'
    response = requests.get(list_url)
    json_data = xmltodict.parse(response.text)
    if 'law' not in json_data['LawSearch'] or len(json_data['LawSearch']['law']) == 0:
        break
    for law in json_data['LawSearch']['law']:
        en_mst.add(law['법령일련번호'])

for page in tqdm(range(1,60)):
    # print(page, "/ 53")
    list_url = f'http://www.law.go.kr/DRF/lawSearch.do?OC={OC}&target=law&page={page}&display=100'
    response = requests.get(list_url)
    json_data = xmltodict.parse(response.text)
    if 'law' not in json_data['LawSearch'] or len(json_data['LawSearch']['law']) == 0:
        break
    for law in json_data['LawSearch']['law']:
        kr_mst.add(law['법령일련번호'])
# Out:
#  90%|████████▉ | 26/29 [00:24<00:02,  1.08it/s]
#  90%|████████▉ | 53/59 [00:55<00:06,  1.05s/it]

# %%
# 현행법령이면서 영문이 있는 것
target_mst = list(kr_mst & en_mst)
len(target_mst)
# Out:
# 838

# %%
rt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-3116bcc4c785> in <cell line: 1>()
# ----> 1 rt
#
# NameError: name 'rt' is not defined

# %% [markdown]
# ## 법령 Parallel 만들기 (매칭시키기)
# - 데이터 개수와 조항 기준으로 확인

# %% [markdown]
# 1. API키 사용하여 [목록] 데이터 크롤링
# 2. 한글, 영어 각각의 [목록] 개수 파악
# 3. 각각의 [MST]를 가져오고 겹치는 것들을 위주로 파악
# 4. 데이터를 보면서 파악
#     * 예시: [법률 제 18487호] 119구조ㆍ구급에 관한 법률 (25-2조에서 형식이 다름을 파악)
# 5. 데이터를 단계적으로 검증이 필요함
#     * 데이터를 불러오면서 발생하는 문제점은 우선 `try` `catch`로 처리하여 오류 케이스 파악
# * [확인1] 법령 [조항] 크롤링할 때 [조]의 개수가 같은지를 기본적으로 파악
# * [확인2] [항]/[조]의 개수 같은지 파악
#     * en은 `\n`기준으로 파악

# %% [markdown]
# ### Check 01: [조문]의 개수가 같은지
# 1. [조문]의 개수가 같은지 파악
#     - 1) [조문]의 개수가 다르다.
#         - 분석 필요
#     - 2) [조문]의 개수가 같다.
#         - 1)번 항목의 경우를 확인하여 더블체크

# %%
# 857
from tqdm import tqdm

same_jo_mst = []
diff_jo_mst = []
err_mst = []
# err_kr_mst = []


# 법령별 정보 추출
for mst in tqdm(target_mst):
    try:
        # en
        url = f'http://www.law.go.kr/DRF/lawService.do?target=elaw&OC={OC}&MST={mst}'
        response_en = requests.get(url)
        if response_en.status_code != 200:
            err_mst.append((mst, response_en.status_code, 'en'))
            continue

        # kr
        url = f'http://www.law.go.kr/DRF/lawService.do?target=law&OC={OC}&MST={mst}'
        response_kr = requests.get(url)
        if response_kr.status_code != 200:
            err_mst.append((mst, response_kr.status_code, 'kr'))
            continue

        # en, kr parsing
        json_data_en = xmltodict.parse(response_en.text)
        json_data_kr = xmltodict.parse(response_kr.text)

        # check 1
        # 조문개수 확인
        if len(json_data_en['Law']['JoSection']['Jo']) == len(json_data_kr['법령']['조문']['조문단위']):
            same_jo_mst.append(mst)
        else:
            diff_jo_mst.append(mst)
    except:
        err_mst.append((mst, 'unknown','need to check'))
# Out:
# 100%|██████████| 838/838 [42:06<00:00,  3.02s/it]

# %%
print("same")
print(same_jo_mst)
print("diff")
print(diff_jo_mst)
print("err")
print(err_mst)
# Out:
# same
# ['245265', '165852', '234455', '198547', '211459', '208541', '246853', '91382', '195529', '235203', '196333', '233995', '208446', '216107', '243061', '238119', '199748', '103228', '234911', '203247', '174491', '179005', '230683', '241159', '231757', '236201', '238915', '238063', '214437', '213783', '171102', '192490', '228817', '194499', '209867', '237401', '201184', '231397', '230805', '243045', '231601', '230497', '244037', '195322', '205801', '207953', '92068', '108467', '245289', '241249', '81706', '195345', '90415', '238757', '231701', '242361', '232253', '244919', '236001', '91501', '243563', '230431', '176245', '236053', '114744', '220883', '238805', '218153', '112289', '149922', '245031', '206701', '231823', '239261', '218005', '233407', '234675', '245245', '231863', '106754', '245653', '234671', '205930', '208699', '245371', '242949', '218013', '244035', '241169', '228131', '236231', '239273', '220857', '188538', '238253', '243671', '86411', '245307', '243849', '209730', '86731', '237105', '238061', '119410', '240065', '236321', '206394', '199779', '137358', '204777', '243669', '247249', '234325', '206734', '241157', '91380', '138747', '232191', '208453', '195536', '199122', '238801', '219139', '162682', '245343', '244927', '157319', '241185', '153871', '245971', '243665', '182009', '245849', '224303', '234339', '183706', '234569', '241801', '228749', '109707', '213519', '231425', '215905', '224695', '238789', '112382', '230677', '244377', '238053', '183569', '197503', '204560', '210145', '228115', '208425', '214237', '224671', '97990', '235555', '208452', '232959', '223431', '238257', '244993', '245015', '228887', '218487', '203671', '195415', '244711', '209699', '212091', '195354', '149822', '117324', '218155', '231391', '231367', '241807', '234277', '244183', '244627', '93181', '238893', '213977', '113196', '238845', '238235', '229311', '132928', '245737', '237883', '218903', '166688', '238109', '205795', '244943', '219091', '232855', '177160', '245281', '243177', '203981', '228111', '103946', '238655', '213225', '231495', '217291', '242823', '216151', '239979', '234333', '218717', '234281', '236111', '205255', '241573', '242891', '243065', '219093', '246917', '165539', '122694', '243699', '240571', '252049', '241541', '96895', '227825', '238833', '231369', '192584', '244995', '192412', '244931', '228147', '247269', '117424', '232879', '212141', '247271', '236817', '223449', '202774', '104326', '234909', '210363', '210257', '203259', '238793', '232081', '219135', '194762', '103962', '244739', '238099', '245917', '245351', '245315', '202628', '241317', '117325', '149559', '195331', '237861', '214441', '83895', '92106', '192519', '239245', '231661', '102534', '243817', '173112', '237135', '198486', '243853', '136693', '224655', '195497', '217403', '213837', '185019', '236195', '214535', '112303', '188047', '222899', '242363', '219067', '228735', '214193', '170996', '195055', '242007', '232881', '243965', '245979', '240077', '167953', '241237', '231375', '238835', '190607', '217691', '239259', '206085', '246637', '242933', '211527', '97989', '223077', '222489', '209662', '203305', '235545', '195072', '212307', '232201', '213779', '234413', '208381', '245349', '232199', '219353', '224669', '242921', '218865', '241529', '244609', '230161', '236951', '242953', '195544', '238751', '245379', '203531', '237543', '237433', '203812', '242881', '244275', '245981', '238827', '224961', '238867', '176090', '235571', '167959', '121956', '136692', '245983', '242947', '227321', '148466', '195056', '241043', '228087', '195997', '218055', '217243', '199798', '217981', '245367', '212189', '116110', '210268', '244033', '218873', '195351', '115683', '220965', '239303', '249059', '215909', '122990', '238057', '240025', '211455', '55761', '183520', '218301', '152098', '249619', '183597', '201137', '242019', '213809', '243041', '224533', '238041', '228083', '232387', '199773', '240071', '222441', '218017', '136666', '166367', '231457', '244 ...
# diff
# ['180480', '233961', '224549', '214545', '203739', '230781', '242955', '235619', '236317', '225139', '239291', '149585', '243079', '239541', '244997', '61603', '238797', '105295', '238059', '228113', '238335', '246165', '241829', '237355', '242401', '228089', '199495', '245973', '210266', '228175', '149553', '222429', '232225', '233423', '218909', '232563', '228065', '237087', '113175', '245747', '239547', '238763', '246569', '238113', '230449', '242975', '234849', '195316', '240063']
# err
# [('231781', 'unknown', 'need to check'), ('204767', 'unknown', 'need to check'), ('234707', 'unknown', 'need to check'), ('165498', 'unknown', 'need to check'), ('231377', 'unknown', 'need to check'), ('153886', 'unknown', 'need to check')]

# %%
json_data_en['Law']['JoSection']

# %%
# [조문]의 개수가 같은 것과 다른 [MST] & Error 발생 [MST]
same_jo_mst = ['231757', '238041', '236053', '213977', '242921', '223449', '245983', '224303', '232611', '218017', '234021', '231661', '213811', '233995', '245343', '243993', '228085', '166366', '195415', '245971', '137358', '188534', '158177', '218015', '244995', '237543', '205685', '245285', '223459', '203981', '171102', '195440', '228887', '243699', '241185', '236195', '241801', '245381', '239485', '245657', '153871', '224547', '243849', '243921', '218013', '211459', '169762', '199748', '246567', '198221', '218055', '213551', '212307', '243853', '238047', '238759', '246281', '183899', '102534', '231601', '217291', '238827', '247271', '245379', '245245', '237883', '195351', '209662', '181386', '223077', '224669', '238855', '206734', '245989', '241249', '192584', '193381', '230783', '224575', '180744', '219403', '241921', '242993', '213225', '232855', '238227', '165539', '192490', '177160', '242873', '234295', '223491', '237401', '228669', '174491', '244377', '186157', '245979', '210145', '205795', '195869', '205996', '244087', '238063', '243045', '230683', '195116', '232959', '227825', '188376', '97990', '234909', '195544', '243669', '113181', '234131', '237861', '243817', '228655', '238039', '224961', '244037', '206085', '203812', '239995', '183706', '112289', '192519', '206564', '218917', '236001', '203531', '215909', '218301', '245009', '238935', '245297', '239261', '211455', '195055', '195398', '232587', '243705', '142443', '228259', '245307', '195117', '209730', '121947', '210726', '230729', '244961', '195051', '242945', '195056', '243113', '208453', '246835', '231457', '198547', '239293', '203247', '236223', '168005', '211727', '116110', '195047', '241237', '195331', '195378', '203305', '232185', '231627', '238229', '242713', '238053', '222505', '228111', '243153', '230549', '236231', '214437', '242363', '81706', '243057', '238119', '240077', '149559', '245849', '231367', '195529', '195997', '215653', '204695', '183569', '195137', '212227', '55761', '211527', '232647', '234707', '236819', '245351', '239241', '231721', '222899', '244183', '192309', '236771', '223451', '150692', '179005', '230157', '239617', '228131', '244779', '234277', '91137', '224533', '245367', '243675', '241169', '246295', '235283', '195322', '195497', '136944', '238861', '247269', '245315', '232643', '239979', '96889', '166367', '228147', '237105', '201148', '205997', '218873', '241043', '236955', '81895', '234409', '217403', '234333', '245981', '202628', '213449', '201184', '245371', '112303', '218717', '208382', '239245', '130810', '234325', '194499', '183597', '236201', '245015', '170996', '167959', '237137', '86731', '219033', '149917', '184935', '220965', '212233', '242929', '242923', '203259', '242007', '224927', '195894', '183520', '184205', '239271', '245235', '179033', '224655', '114744', '213855', '238109', '239269', '234671', '242095', '181623', '246637', '219039', '109707', '129332', '176245', '122694', '213837', '227321', '240031', '230525', '232881', '247249', '234281', '200682', '232879', '216107', '231503', '246853', '230431', '208381', '218907', '117325', '236251', '237359', '228087', '240097', '121956', '210257', '209699', '223983', '244711', '216183', '231795', '242949', '243041', '242881', '240055', '138747', '228115', '166688', '238801', '204777', '165852', '219135', '244275', '219239', '252049', '236111', '239259', '235203', '84504', '208541', '230497', '201190', '93181', '218135', '233211', '244919', '245289', '199798', '243063', '205846', '204560', '240065', '140592', '216173', '238257', '195501', '243065', '249059', '228121', '232893', '242999', '234911', '243059', '230805', '230513', '244969', '234675', '97987', '119410', '239303', '232199', '190607', '182009', '218865', '217995', '221707', '242989', '214441', '236321', '204775', '241159', '239469', '243115', '169467', '195052', '188047', '243379', '243965', '106831', '238793', '244367', '207953', '103946', '211885', '203671', '198486', '241157', '244133', '232869', '191150', '83896', '211551', '179505', '243061', '218487', '228169', '247231', '205930', '152098', '165523', '219353', '238243', '240069', '205742', '240351', '108467', '222423', '214319', '91501', '214473', '228749', '219067', '178983', '243177', '217299', '117324', '148466', '231373', '223431', '245305', '196333', '205811', '235545', '214193', '169502', '203249', '245265', '195068', '243563', '238655', '237135', '213857', '240025', '219563', '198564', '198226', '216103', '217981', '243939', '202626', '238867', '244035', '242953', '230353', '224107', '216179', '215763', '220373', '231391', '113964', '130656', '202774', '115683', '231369', '240033', '208601', '231755', '195536', '242983', '103863', '164562', '185019', '224583', '178989', '244943', '237891', '204767', '231491', '242941', '180465', '224671', '201143', '213527', '234017', '149922', '242361', '176090', '239491', '192435', '88893', '136693', '223615', '239477', '234569', '248315', '231331', '92106', '244277', '122986', '200173', '129262', '232671', '203835', '197503', '121952', '103947', '242937', '232897', '242823', '243099', '104326', '237439', '202765', '213779', '235555', '218051', '245393', '213783', '103962', '208452', '218005', '199779', '234339', '234825', '232191', '246917', '232081', '136692', '244701', '86411', '232841', '241529', '136014', '234299', '238915', '244039', '170988', '91382', '240571', '202910', '230223', '235999', '236145', '203170', '199122', '232253', '231377', '237433', '240071', '182175', '103228', '122701', '231537', '214535', '238097', '238919', '218661', '224695', '205801', '213809', '232231', '212141', '238805', '97989', '238057', '231823', '229311', '168725', '117424', '224385', '192412', '246157', '136917', '230677', '229829', '238893', '244993', '91383', '210258', '214403', '237131', '205255', '220877', '244739', '244801', '214551', '237517', '237515', '244267', '245349', '198474', '97050', '245031', '206142', '244033', '230421', '231375', '244921', '245001', '231495', '239273', '228735', '206470', '103869', '249977', '238061', '188538', '98243', '213519', '195078', '235587', '216131', '244627', '228083', '236951', '238751', '241541', '213803', '239893', '84010', '236817', '205700', '90415', '231701', '239301', '214161', '246123', '157319', '194522', '209645', '241935', '122990', '211799', '204768', '92068', '234455', '240245', '234271', '236113', '192018', '203669', '199499', '218325', '180327', '244609', '237421', '199083', '245917', '206394', '208699', '243671', '219361', '188381', '243147', '241139', '243073', '218903', '166363', '242019', '247189', '223575', '216151', '96895', '227407', '232201', '195072', '236229', '242979', '217243', '136666', '235839', '230161', '241573', '242947', '162682', '242933', '195667', '228817', '238681', '206701', '245281', '244931', '231863', '219093', '238099', '167953', '113196', '199494', '222549', '244933', '224923', '210268', '243667', '208446', '214129', '223079', '219131', '232139', '244975', '242931', '245851', '244119', '239493', '172201', '212189', '219139', '223461', '91380', '244703', '245987', '231425', '249619', '238833', '242939', '153866', '234349', '167446', '220883', '210368', '218143', '149822', '245227', '142442', '217691', '231397', '203169', '195354', '241317', '194762', '222441', '244253', '245975', '218113', '112382', '243665', '136675', '234413', '230255', '222489', '228071', '211635', '244965', '241807', '232271', '233381', '238235', '213521', '83895', '114769', '233407', '242919', '208425', '233829', '245653', '218155', '195716', '245003', '103861', '199773', '195091', '224917', '195200', '247139', '215905', '220857', '209867', '235571', '244927', '242891', '212091', '169302', '238253', '219107', '149564', '202316', '205233', '198482', '234719', '195470', '201137', '106754', '214237', '219091', '215923', '238835', '210363', '103864', '244855', '218153', '150369', '173112', '195345', '239311', '232387', '132928', '238789', '245737', '238845', '238757']
diff_jo_mst = ['243117', '239547', '218909', '233961', '246165', '228175', '243935', '237355', '105295', '245747', '238059', '235619', '149585', '243079', '239541', '242955', '243171', '61603', '237087', '222429', '234849', '241829', '214545', '203739', '228065', '246569', '242975', '238335', '195316', '236317', '199495', '238763', '235535', '113175', '238797', '180480', '244997', '224549', '149553', '240063', '232225', '228113', '195441', '225139', '228089', '230449', '230781', '238113', '232563', '210266', '230429', '233423', '239291', '245973', '242401']
err_mst = [('153886', 'unknown', 'need to check'), ('165498', 'unknown', 'need to check'), ('231781', 'unknown', 'need to check')]

# %% [markdown]
# ### Check 02: 조문의 항들을 기준으로 처리
# - 같은 항에도 en에는 여러 버전이 있는 경우가 있었음
# [순서]
# 1. `kr`에서 조문의 항들이 유니크한지 파악
#     - `set()`과 `list()`개수가 같은지
# 2. `kr`에서 조문의 [항]과 `en`에서 조문의 [항]이 일치하는지
#     - 일치
#         - 1)
#     - 불일치: 일반적으로 `kr`에서의 [항] 하나에 여러 `en`의 [항]이 연결된다. 방법은 아래와 같다.
#         - 1) 제거 -> 이쪽이 더 나을듯
#         - 2) 매칭

# %%
## 데이터 저장하는 과정이 필요함

# %%
# @title
def check_jo(json_data_kr, json_data_en):
    tmp = list()
    curr = -1
    for t in json_data_kr['법령']['조문']['조문단위']:
        if t['조문여부'] == '조문':
            if '조문가지번호' in t:
                tmp.append(f"{int(curr)}-{t['조문번호']}-{t['조문가지번호']}")#({t['조문시행일자'] if '조문시행일자' in t else ''})")
            else:
                tmp.append(f"{int(curr)}-{t['조문번호']}")
        if t['조문여부'] == '전문':
            curr = t['조문번호']
    tmp2 = list()
    curr = -1
    for t in json_data_en['Law']['JoSection']['Jo']:
        if t['joYn'] == 'Y':
            if 'joBrNo' in t and int(t['joBrNo']) != 0:
                tmp2.append(f"{int(curr)}-{int(t['joNo'])}-{int(t['joBrNo'])}")
            else:
                tmp2.append(f"{int(curr)}-{int(t['joNo'])}")
        if t['joYn'] == 'N':
            curr = t['joNo']
    return tmp, tmp2 # kr, en
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-724319bc3064> in <cell line: 25>()
#      23
#      24 using_mst = []
# ---> 25 for file in os.listdir('Data/kr/'):
#      26     _, a = os.path.split(f'Data/kr/{file}')
#      27     filename, form = os.path.splitext(a)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/kr/'

# %%
en_data, kr_data = [], []
for file in os.listdir('Data/kr/'):
    _, a = os.path.split(f'Data/kr/{file}')
    filename, form = os.path.splitext(a)
    filename = filename[3:]
    with open(f'Data/kr/{file}', 'r') as f:
        json_data_kr = json.load(f)
    with open(f'Data/en/en_{filename}.json', 'r') as f:
        json_data_en = json.load(f)
    cnt_kr, cnt_en = check_jo(json_data_kr, json_data_en)
    if cnt_kr == cnt_en:
        for kr, en in zip(json_data_kr['법령']['조문']['조문단위'], json_data_en['Law']['JoSection']['Jo']):
            cnt = 1
            # print(kr['조문내용'])
            if '항' in kr:
                kr_h = [kr['항']] if type(kr['항']) == dict else kr['항']
                cnt += len(kr_h)
                for kr_hang in kr_h:
                    if '항내용' not in kr_hang:
                        cnt -= 1
                    else:
                        pass
                        # print("\t", kr_hang['항내용'])
                    if '호' in kr_hang:
                        kr_hos = [kr_hang['호']] if type(kr_hang['호']) == dict else kr_hang['호']
                        cnt += len(kr_hos)
                        for kr_ho in kr_hos:
                            if '호내용' not in kr_ho:
                                cnt -= 1
                            else:
                                pass
                                # print("\t\t", kr_ho['호내용'])
                            if '목' in kr_ho:
                                cnt += len(kr_ho['목'])
                                for kr_mok in kr_ho['목']:
                                    if '목내용' not in kr_mok:
                                        cnt -= 1
                                    else:
                                        # print("\t\t\t", kr_mok['목내용'])
                                        pass
            en_val = len(en['joCts'].replace(') (1)', ')\n(1)').split('\n'))
            en_val2 = sum([1 if t.strip().startswith('[') else 0 for t in en['joCts'].split('\n')])
            en_val -= en_val2
            if cnt == en_val:
                en_law = en['joCts'].replace(') (1)', ')\n  (1)').split('\n')
                cnt = 0
                if '항' in kr:
                    kr_h = [kr['항']] if type(kr['항']) == dict else kr['항']
                    # print(kr['조문내용'], en_law[cnt])
                    kr_data.append(kr['조문내용'])
                    en_data.append(en_law[cnt])
                    cnt += 1
                    for kr_hang in kr_h:
                        if '항내용' not in kr_hang:
                            pass
                        else:
                            pass
                            # print(kr_hang['항내용'], en_law[cnt])
                            kr_data.append(kr_hang['항내용'])
                            en_data.append(en_law[cnt])
                            cnt += 1
                        if '호' in kr_hang:
                            kr_hos = [kr_hang['호']] if type(kr_hang['호']) == dict else kr_hang['호']
                            for kr_ho in kr_hos:
                                if '호내용' not in kr_ho:
                                    pass
                                else:
                                    # print("\t\t", kr_ho['호내용'], en_law[cnt])
                                    kr_data.append(kr_ho['호내용'])
                                    en_data.append(en_law[cnt])
                                    cnt += 1
                                    pass

                                if '목' in kr_ho:
                                    for kr_mok in kr_ho['목']:
                                        if '목내용' not in kr_mok:
                                            pass
                                        else:
                                            # print("\t\t\t", kr_mok['목내용'], en_law[cnt])
                                            kr_data.append(kr_mok['목내용'])
                                            en_data.append(en_law[cnt])
                                            cnt += 1
                                            pass

# %%
with open('kr.txt','w') as f:
    for k in kr_data:
        f.write(f"{k.strip()}\n")
with open('en.txt','w') as f:
    for k in en_data:
        f.write(f"{k.strip()}\n")

# %%
#----------------------------------------------------#

# %%
len(en_data)

# %%
en_law = en['joCts'].replace(') (1)', ')\n  (1)').split('\n')
cnt = 0
if '항' in kr:
    kr_h = [kr['항']] if type(kr['항']) == dict else kr['항']
    print(kr['조문내용'], en_law[cnt])
    cnt += 1
    for kr_hang in kr_h:
        if '항내용' not in kr_hang:
            pass
        else:
            pass
            print(kr_hang['항내용'], en_law[cnt])
            cnt += 1
        if '호' in kr_hang:
            kr_hos = [kr_hang['호']] if type(kr_hang['호']) == dict else kr_hang['호']
            for kr_ho in kr_hos:
                if '호내용' not in kr_ho:
                    pass
                else:
                    print("\t\t", kr_ho['호내용'], en_law[cnt])
                    cnt += 1
                    pass

                if '목' in kr_ho:
                    for kr_mok in kr_ho['목']:
                        if '목내용' not in kr_mok:
                            pass
                        else:
                            print("\t\t\t", kr_mok['목내용'], en_law[cnt])
                            cnt += 1
                            pass

# %%
_, a = os.path.split('Data/kr/kr_55761.json')
filename, _ = os.path.splitext(a)
filename[3:], _

# %%
json_data_kr['법령']['조문']

# %%
tmp = list()
curr = -1
for t in json_data_kr['법령']['조문']['조문단위']:
    if t['조문여부'] == '조문':
        if '조문가지번호' in t:
            tmp.append(f"{int(curr)}-{t['조문번호']}-{t['조문가지번호']}")#({t['조문시행일자'] if '조문시행일자' in t else ''})")
        else:
            tmp.append(f"{int(curr)}-{t['조문번호']}")
    if t['조문여부'] == '전문':
        curr = t['조문번호']
tmp2 = list()
curr = -1
for t in json_data_en['Law']['JoSection']['Jo']:
    if t['joYn'] == 'Y':
        if 'joBrNo' in t and int(t['joBrNo']) != 0:
            tmp2.append(f"{int(curr)}-{int(t['joNo'])}-{int(t['joBrNo'])}")
        else:
            tmp2.append(f"{int(curr)}-{int(t['joNo'])}")
    if t['joYn'] == 'N':
        curr = t['joNo']

# %%
len(set(tmp2)), len(set(tmp)), len(tmp)

# %% [markdown]
# * 법령 : 243117
# * 6조 "CDATA[ 제6조(마약류취급자의 허가 등) "에서 en는 개정 이전의 자료도 같이 포함되어 있지만 특별한 구분법이 없음.

# %%
len(set(tmp2)), len(set(tmp)), len(tmp)

# %%
for t, tt in zip(tmp2, tmp):
    print(t, tt)

# %%
len(tmp2), len(tmp)

# %% [markdown]
# # 데이터 전처리 (<> 없애기) X

# %%
data_kr = []
data_en = []
with open('kr.txt','r') as f:
    data_kr = f.read().split('\n')[:-1]
with open('en.txt','r') as f:
    data_en = f.read().split('\n')[:-1]

# %%
data_en

# %% [markdown]
# # 참조만하기

# %%
# 데이터 개수 en: 2586 kr: 5273
# 예상페이지 수: 26page (2586 // 100)
from tqdm import tqdm

same_jo_mst = []
diff_jo_mst = []
err_en_mst = []
err_kr_mst = []

# 페이지에 따라 추출
for page in range(1,27):
    print(page, "/ 26")
    list_url = f'http://www.law.go.kr/DRF/lawSearch.do?OC={OC}&target=elaw&page={page}&display=100'
    response = requests.get(list_url)
    json_data = xmltodict.parse(response.text)

    # 법령별 정보 추출
    for law in tqdm(json_data['LawSearch']['law']):
        mst = law['법령일련번호']
        # en
        url = f'http://www.law.go.kr/DRF/lawService.do?target=elaw&OC={OC}&MST={mst}'
        response_en = requests.get(url)
        if response_en.status_code != 200:
            err_en_mst.append((mst, response_en.status_code))
            continue

        # kr
        url = f'http://www.law.go.kr/DRF/lawService.do?target=law&OC={OC}&MST={mst}'
        response_kr = requests.get(url)
        if response_kr.status_code != 200:
            err_kr_mst.append((mst, response_kr.status_code))
            continue

        # en, kr parsing
        json_data_en = xmltodict.parse(response_en.text)
        json_data_kr = xmltodict.parse(response_kr.text)

        # check 1
        # 조문개수 확인
        if len(json_data_en['Law']['JoSection']['Jo']) == len(json_data_kr['법령']['조문']['조문단위']):
            same_jo_mst.append(mst)
        else:
            diff_jo_mst.append(mst)


        # print(law['법령상세링크'], law['법령일련번호'])
# Out:
# 1 / 26
#  66%|██████▌   | 66/100 [04:30<02:19,  4.10s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-9a0270a51163> in <cell line: 11>()
#      38         # check 1
#      39         # 조문개수 확인
# ---> 40         if len(json_data_en['Law']['JoSection']['Jo']) == len(json_data_kr['법령']['조문']['조문단위']):
#      41             same_jo_mst.append(mst)
#      42         else:
#
# TypeError: 'NoneType' object is not subscriptable

# %%
data = requests.get('https://www.law.go.kr/lawEngBodyCompareInfoP.do?lsNm=119%EA%B5%AC%EC%A1%B0%E3%86%8D%EA%B5%AC%EA%B8%89%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0&lsId=011349&lsiSeq=228097&gubun=EngLs&ancYnChk=')
data.text

# %%
from bs4 import BeautifulSoup
import json

soup = BeautifulSoup(data.text, 'html.parser')
soup.find_all('p')

# %% [markdown]
# # 사용할 법령 따로 저장
# [기본설정]부분을 실행 후 진행
#
# (error가 발생한 mst는 제외)

# %%
# 857
from tqdm import tqdm

same_jo_mst = []
diff_jo_mst = []
err_mst = []

# 법령별 정보 추출
for mst in tqdm(target_mst):
    try:
        # en
        url = f'http://www.law.go.kr/DRF/lawService.do?target=elaw&OC={OC}&MST={mst}'
        response_en = requests.get(url)
        if response_en.status_code != 200:
            err_mst.append((mst, response_en.status_code, 'en'))
            continue

        # kr
        url = f'http://www.law.go.kr/DRF/lawService.do?target=law&OC={OC}&MST={mst}'
        response_kr = requests.get(url)
        if response_kr.status_code != 200:
            err_mst.append((mst, response_kr.status_code, 'kr'))
            continue

        # en, kr parsing
        json_data_en = xmltodict.parse(response_en.text)
        json_data_kr = xmltodict.parse(response_kr.text)

        # check 1
        # 조문개수 확인
        if len(json_data_en['Law']['JoSection']['Jo']) == len(json_data_kr['법령']['조문']['조문단위']):
            same_jo_mst.append(mst)
        else:
            diff_jo_mst.append(mst)
    except:
        err_mst.append((mst, 'unknown','need to check'))

# %%
BASE = '/content/drive/MyDrive/취업/일지/230509_국민은행_1차합격/인턴십/AI1차과제/Data/'
lang_type = 'en'
for mst in tqdm(same_jo_mst):
    url = f'http://www.law.go.kr/DRF/lawService.do?target=elaw&OC={OC}&MST={mst}'
    response_en = requests.get(url)
    json_data_en = xmltodict.parse(response_en.text)
    with open(BASE+lang_type+f"/en_{mst}.json", 'w') as f:
        json.dump(json_data_en, indent=4, ensure_ascii=False, fp=f)

# %%
BASE = '/content/drive/MyDrive/취업/일지/230509_국민은행_1차합격/인턴십/AI1차과제/Data/'
lang_type = 'kr'
for mst in tqdm(same_jo_mst):
    url = f'http://www.law.go.kr/DRF/lawService.do?target=law&OC={OC}&MST={mst}'
    response_kr = requests.get(url)
    json_data_kr = xmltodict.parse(response_kr.text)
    with open(BASE+lang_type+f"/kr_{mst}.json", 'w') as f:
        json.dump(json_data_kr, indent=4, ensure_ascii=False, fp=f)

# %%
BASE = ''
lang_type = 'kr'
with open(BASE+lang_type+f"/{'test'}.json", 'w') as f:
    json.dump(json_data_kr, indent=4, ensure_ascii=False, fp=f)

# %%
with open(BASE+lang_type+f"/{'test'}.json", 'r') as f:
    t = json.load(f)
